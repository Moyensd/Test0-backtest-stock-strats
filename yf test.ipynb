# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

Apple = yf.download("AAPL", start = "2010-01-01", end = "2023-01-01")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
Apple
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-01-04    7.622500    7.660714    7.585000    7.643214    6.487535
# 2010-01-05    7.664286    7.699643    7.616071    7.656429    6.498749
# 2010-01-06    7.656429    7.686786    7.526786    7.534643    6.395380
# 2010-01-07    7.562500    7.571429    7.466071    7.520714    6.383556
# 2010-01-08    7.510714    7.571429    7.466429    7.570714    6.425996
# ...                ...         ...         ...         ...         ...
# 2022-12-23  130.919998  132.419998  129.639999  131.860001  131.299820
# 2022-12-27  131.380005  131.410004  128.720001  130.029999  129.477585
# 2022-12-28  129.669998  131.029999  125.870003  126.040001  125.504539
# 2022-12-29  127.989998  130.479996  127.730003  129.610001  129.059372
# 2022-12-30  128.410004  129.949997  127.430000  129.929993  129.378006
#
#                Volume
# Date
# 2010-01-04  493729600
# 2010-01-05  601904800
# 2010-01-06  552160000
# 2010-01-07  477131200
# 2010-01-08  447610800
# ...               ...
# 2022-12-23   63814900
# 2022-12-27   69007800
# 2022-12-28   85438400
# 2022-12-29   75703700
# 2022-12-30   77034200
#
# [3272 rows x 6 columns]

# %%
a = [1,2,3,4]
a
# Out:
# [1, 2, 3, 4]

# %%
ticker = ["SPY", "AAPLE", "KO"]

# %%
ticker
# Out:
# ['SPY', 'AAPLE', 'KO']

# %%
stocks = yf.download(ticker, start = "2010-01-01", end = "2023-01-01")
# Out:
# [*********************100%%**********************]  3 of 3 completed
# 1 Failed download:
# ['AAPLE']: Exception('%ticker%: No timezone found, symbol may be delisted')

# %%
ticker = ["SPY", "AAPL", "KO"]

# %%
stocks = yf.download(ticker, start = "2010-01-01", end = "2023-01-01")
# Out:
# [*********************100%%**********************]  3 of 3 completed

# %%
stocks
# Out:
#              Adj Close                              Close             \
#                   AAPL         KO         SPY        AAPL         KO
# Date
# 2010-01-04    6.487533  18.645304   87.483215    7.643214  28.520000
# 2010-01-05    6.498750  18.419765   87.714775    7.656429  28.174999
# 2010-01-06    6.395379  18.413221   87.776535    7.534643  28.165001
# 2010-01-07    6.383556  18.367462   88.147087    7.520714  28.094999
# 2010-01-08    6.425995  18.027510   88.440392    7.570714  27.575001
# ...                ...        ...         ...         ...        ...
# 2022-12-23  131.299820  62.360737  378.706665  131.860001  63.820000
# 2022-12-27  129.477585  62.741817  377.213226  130.029999  64.209999
# 2022-12-28  125.504539  62.116451  372.525269  126.040001  63.570000
# 2022-12-29  129.059372  62.487762  379.230835  129.610001  63.950001
# 2022-12-30  129.378006  62.155540  378.231934  129.929993  63.610001
#
#                               High                                Low  \
#                    SPY        AAPL         KO         SPY        AAPL
# Date
# 2010-01-04  113.330002    7.660714  28.610001  113.389999    7.585000
# 2010-01-05  113.629997    7.699643  28.495001  113.680000    7.616071
# 2010-01-06  113.709999    7.686786  28.219999  113.989998    7.526786
# 2010-01-07  114.190002    7.571429  28.184999  114.330002    7.466071
# 2010-01-08  114.570000    7.571429  27.820000  114.620003    7.466429
# ...                ...         ...        ...         ...         ...
# 2022-12-23  382.910004  132.419998  63.869999  383.059998  129.639999
# 2022-12-27  381.399994  131.410004  64.290001  383.149994  128.720001
# 2022-12-28  376.660004  131.029999  64.650002  383.390015  125.870003
# 2022-12-29  383.440002  130.479996  64.150002  384.350006  127.730003
# 2022-12-30  382.429993  129.949997  63.919998  382.579987  127.430000
#
#                                          Open                         \
#                    KO         SPY        AAPL         KO         SPY
# Date
# 2010-01-04  28.450001  111.510002    7.622500  28.580000  112.370003
# 2010-01-05  28.070000  112.849998    7.664286  28.424999  113.260002
# 2010-01-06  27.990000  113.430000    7.656429  28.174999  113.519997
# 2010-01-07  27.875000  113.180000    7.562500  28.165001  113.500000
# 2010-01-08  27.375000  113.660004    7.510714  27.730000  113.889999
# ...               ...         ...         ...        ...         ...
# 2022-12-23  63.200001  378.029999  130.919998  63.500000  379.649994
# 2022-12-27  63.709999  379.649994  131.380005  63.930000  382.790009
# 2022-12-28  63.490002  376.420013  129.669998  64.459999  381.329987
# 2022-12-29  63.700001  379.079987  127.989998  63.799999  379.630005
# 2022-12-30  63.169998  378.429993  128.410004  63.919998  380.640015
#
#                Volume
#                  AAPL        KO        SPY
# Date
# 2010-01-04  493729600  13870400  118944600
# 2010-01-05  601904800  23172400  111579900
# 2010-01-06  552160000  19264600  116074400
# 2010-01-07  477131200  13234600  131091100
# 2010-01-08  447610800  28712400  126402800
# ...               ...       ...        ...
# 2022-12-23   63814900   6463300   59857300
# 2022-12-27   69007800   7320700   51638200
# 2022-12-28   85438400   7159400   70911500
# 2022-12-29   75703700   7169300   66970900
# 2022-12-30   77034200   7650200   84022200
#
# [3272 rows x 18 columns]

# %%
stocks.head()
# Out:
#            Adj Close                           Close                         \
#                 AAPL         KO        SPY      AAPL         KO         SPY
# Date
# 2010-01-04  6.487533  18.645304  87.483215  7.643214  28.520000  113.330002
# 2010-01-05  6.498750  18.419765  87.714775  7.656429  28.174999  113.629997
# 2010-01-06  6.395379  18.413221  87.776535  7.534643  28.165001  113.709999
# 2010-01-07  6.383556  18.367462  88.147087  7.520714  28.094999  114.190002
# 2010-01-08  6.425995  18.027510  88.440392  7.570714  27.575001  114.570000
#
#                 High                              Low                         \
#                 AAPL         KO         SPY      AAPL         KO         SPY
# Date
# 2010-01-04  7.660714  28.610001  113.389999  7.585000  28.450001  111.510002
# 2010-01-05  7.699643  28.495001  113.680000  7.616071  28.070000  112.849998
# 2010-01-06  7.686786  28.219999  113.989998  7.526786  27.990000  113.430000
# 2010-01-07  7.571429  28.184999  114.330002  7.466071  27.875000  113.180000
# 2010-01-08  7.571429  27.820000  114.620003  7.466429  27.375000  113.660004
#
#                 Open                            Volume
#                 AAPL         KO         SPY       AAPL        KO        SPY
# Date
# 2010-01-04  7.622500  28.580000  112.370003  493729600  13870400  118944600
# 2010-01-05  7.664286  28.424999  113.260002  601904800  23172400  111579900
# 2010-01-06  7.656429  28.174999  113.519997  552160000  19264600  116074400
# 2010-01-07  7.562500  28.165001  113.500000  477131200  13234600  131091100
# 2010-01-08  7.510714  27.730000  113.889999  447610800  28712400  126402800

# %%
stocks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3272 entries, 2010-01-04 to 2022-12-30
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   (Adj Close, AAPL)  3272 non-null   float64
#  1   (Adj Close, KO)    3272 non-null   float64
#  2   (Adj Close, SPY)   3272 non-null   float64
#  3   (Close, AAPL)      3272 non-null   float64
#  4   (Close, KO)        3272 non-null   float64
#  5   (Close, SPY)       3272 non-null   float64
#  6   (High, AAPL)       3272 non-null   float64
#  7   (High, KO)         3272 non-null   float64
#  8   (High, SPY)        3272 non-null   float64
#  9   (Low, AAPL)        3272 non-null   float64
#  10  (Low, KO)          3272 non-null   float64
#  11  (Low, SPY)         3272 non-null   float64
#  12  (Open, AAPL)       3272 non-null   float64
#  13  (Open, KO)         3272 non-null   float64
#  14  (Open, SPY)        3272 non-null   float64
#  15  (Volume, AAPL)     3272 non-null   int64
#  16  (Volume, KO)       3272 non-null   int64
#  17  (Volume, SPY)      3272 non-null   int64
# dtypes: float64(15), int64(3)
# memory usage: 485.7 KB

# %%
stocks.to_csv("stockstest.csv")

# %%
stocks = pd.read_csv("stockstest.csv")

# %%
stocks = pd.read_csv("stockstest.csv")

# %%
stocks
# Out:
#       Unnamed: 0           Adj Close         Adj Close.1        Adj Close.2  \
# 0            NaN                AAPL                  KO                SPY
# 1           Date                 NaN                 NaN                NaN
# 2     2010-01-04   6.487533092498779   18.64530372619629  87.48321533203125
# 3     2010-01-05   6.498749732971191   18.41976547241211  87.71477508544922
# 4     2010-01-06   6.395378589630127   18.41322135925293  87.77653503417969
# ...          ...                 ...                 ...                ...
# 3269  2022-12-23  131.29981994628906   62.36073684692383  378.7066650390625
# 3270  2022-12-27   129.4775848388672  62.741817474365234  377.2132263183594
# 3271  2022-12-28   125.5045394897461  62.116451263427734  372.5252685546875
# 3272  2022-12-29   129.0593719482422  62.487762451171875  379.2308349609375
# 3273  2022-12-30   129.3780059814453  62.155540466308594    378.23193359375
#
#                    Close             Close.1             Close.2  \
# 0                   AAPL                  KO                 SPY
# 1                    NaN                 NaN                 NaN
# 2      7.643214225769043  28.520000457763672  113.33000183105469
# 3      7.656428813934326  28.174999237060547  113.62999725341797
# 4      7.534643173217773  28.165000915527344  113.70999908447266
# ...                  ...                 ...                 ...
# 3269  131.86000061035156   63.81999969482422   382.9100036621094
# 3270  130.02999877929688   64.20999908447266   381.3999938964844
# 3271  126.04000091552734   63.56999969482422   376.6600036621094
# 3272  129.61000061035156   63.95000076293945  383.44000244140625
# 3273  129.92999267578125   63.61000061035156  382.42999267578125
#
#                     High              High.1              High.2  \
# 0                   AAPL                  KO                 SPY
# 1                    NaN                 NaN                 NaN
# 2      7.660714149475098  28.610000610351562  113.38999938964844
# 3      7.699643135070801    28.4950008392334  113.68000030517578
# 4       7.68678617477417  28.219999313354492  113.98999786376953
# ...                  ...                 ...                 ...
# 3269   132.4199981689453  63.869998931884766  383.05999755859375
# 3270  131.41000366210938   64.29000091552734   383.1499938964844
# 3271  131.02999877929688    64.6500015258789   383.3900146484375
# 3272  130.47999572753906    64.1500015258789   384.3500061035156
# 3273   129.9499969482422   63.91999816894531   382.5799865722656
#
#                      Low               Low.1               Low.2  \
# 0                   AAPL                  KO                 SPY
# 1                    NaN                 NaN                 NaN
# 2      7.585000038146973  28.450000762939453  111.51000213623047
# 3     7.6160712242126465   28.06999969482422   112.8499984741211
# 4      7.526785850524902  27.989999771118164  113.43000030517578
# ...                  ...                 ...                 ...
# 3269  129.63999938964844   63.20000076293945   378.0299987792969
# 3270  128.72000122070312  63.709999084472656   379.6499938964844
# 3271  125.87000274658203    63.4900016784668   376.4200134277344
# 3272   127.7300033569336   63.70000076293945   379.0799865722656
# 3273  127.43000030517578   63.16999816894531  378.42999267578125
#
#                     Open              Open.1              Open.2     Volume  \
# 0                   AAPL                  KO                 SPY       AAPL
# 1                    NaN                 NaN                 NaN        NaN
# 2      7.622499942779541  28.579999923706055  112.37000274658203  493729600
# 3      7.664286136627197  28.424999237060547  113.26000213623047  601904800
# 4      7.656428813934326  28.174999237060547   113.5199966430664  552160000
# ...                  ...                 ...                 ...        ...
# 3269   130.9199981689453                63.5   379.6499938964844   63814900
# 3270   131.3800048828125   63.93000030517578   382.7900085449219   69007800
# 3271   129.6699981689453   64.45999908447266   381.3299865722656   85438400
# 3272  127.98999786376953   63.79999923706055   379.6300048828125   75703700
# 3273  128.41000366210938   63.91999816894531   380.6400146484375   77034200
#
#       Volume.1   Volume.2
# 0           KO        SPY
# 1          NaN        NaN
# 2     13870400  118944600
# 3     23172400  111579900
# 4     19264600  116074400
# ...        ...        ...
# 3269   6463300   59857300
# 3270   7320700   51638200
# 3271   7159400   70911500
# 3272   7169300   66970900
# 3273   7650200   84022200
#
# [3274 rows x 19 columns]

# %%
stocks = pd.read_csv("stockstest.csv", header = [0,1])

# %%
stocks
# Out:
#      Unnamed: 0_level_0   Adj Close                              Close  \
#      Unnamed: 0_level_1        AAPL         KO         SPY        AAPL
# 0                  Date         NaN        NaN         NaN         NaN
# 1            2010-01-04    6.487533  18.645304   87.483215    7.643214
# 2            2010-01-05    6.498750  18.419765   87.714775    7.656429
# 3            2010-01-06    6.395379  18.413221   87.776535    7.534643
# 4            2010-01-07    6.383556  18.367462   88.147087    7.520714
# ...                 ...         ...        ...         ...         ...
# 3268         2022-12-23  131.299820  62.360737  378.706665  131.860001
# 3269         2022-12-27  129.477585  62.741817  377.213226  130.029999
# 3270         2022-12-28  125.504539  62.116451  372.525269  126.040001
# 3271         2022-12-29  129.059372  62.487762  379.230835  129.610001
# 3272         2022-12-30  129.378006  62.155540  378.231934  129.929993
#
#                                    High                                Low  \
#              KO         SPY        AAPL         KO         SPY        AAPL
# 0           NaN         NaN         NaN        NaN         NaN         NaN
# 1     28.520000  113.330002    7.660714  28.610001  113.389999    7.585000
# 2     28.174999  113.629997    7.699643  28.495001  113.680000    7.616071
# 3     28.165001  113.709999    7.686786  28.219999  113.989998    7.526786
# 4     28.094999  114.190002    7.571429  28.184999  114.330002    7.466071
# ...         ...         ...         ...        ...         ...         ...
# 3268  63.820000  382.910004  132.419998  63.869999  383.059998  129.639999
# 3269  64.209999  381.399994  131.410004  64.290001  383.149994  128.720001
# 3270  63.570000  376.660004  131.029999  64.650002  383.390015  125.870003
# 3271  63.950001  383.440002  130.479996  64.150002  384.350006  127.730003
# 3272  63.610001  382.429993  129.949997  63.919998  382.579987  127.430000
#
#                                    Open                              Volume  \
#              KO         SPY        AAPL         KO         SPY         AAPL
# 0           NaN         NaN         NaN        NaN         NaN          NaN
# 1     28.450001  111.510002    7.622500  28.580000  112.370003  493729600.0
# 2     28.070000  112.849998    7.664286  28.424999  113.260002  601904800.0
# 3     27.990000  113.430000    7.656429  28.174999  113.519997  552160000.0
# 4     27.875000  113.180000    7.562500  28.165001  113.500000  477131200.0
# ...         ...         ...         ...        ...         ...          ...
# 3268  63.200001  378.029999  130.919998  63.500000  379.649994   63814900.0
# 3269  63.709999  379.649994  131.380005  63.930000  382.790009   69007800.0
# 3270  63.490002  376.420013  129.669998  64.459999  381.329987   85438400.0
# 3271  63.700001  379.079987  127.989998  63.799999  379.630005   75703700.0
# 3272  63.169998  378.429993  128.410004  63.919998  380.640015   77034200.0
#
#
#               KO          SPY
# 0            NaN          NaN
# 1     13870400.0  118944600.0
# 2     23172400.0  111579900.0
# 3     19264600.0  116074400.0
# 4     13234600.0  131091100.0
# ...          ...          ...
# 3268   6463300.0   59857300.0
# 3269   7320700.0   51638200.0
# 3270   7159400.0   70911500.0
# 3271   7169300.0   66970900.0
# 3272   7650200.0   84022200.0
#
# [3273 rows x 19 columns]

# %%
stocks = pd.read_csv("stockstest.csv", header = [0,1], index_col=[0])

# %%
stocks
# Out:
#              Adj Close                              Close             \
#                   AAPL         KO         SPY        AAPL         KO
# Date
# 2010-01-04    6.487533  18.645304   87.483215    7.643214  28.520000
# 2010-01-05    6.498750  18.419765   87.714775    7.656429  28.174999
# 2010-01-06    6.395379  18.413221   87.776535    7.534643  28.165001
# 2010-01-07    6.383556  18.367462   88.147087    7.520714  28.094999
# 2010-01-08    6.425995  18.027510   88.440392    7.570714  27.575001
# ...                ...        ...         ...         ...        ...
# 2022-12-23  131.299820  62.360737  378.706665  131.860001  63.820000
# 2022-12-27  129.477585  62.741817  377.213226  130.029999  64.209999
# 2022-12-28  125.504539  62.116451  372.525269  126.040001  63.570000
# 2022-12-29  129.059372  62.487762  379.230835  129.610001  63.950001
# 2022-12-30  129.378006  62.155540  378.231934  129.929993  63.610001
#
#                               High                                Low  \
#                    SPY        AAPL         KO         SPY        AAPL
# Date
# 2010-01-04  113.330002    7.660714  28.610001  113.389999    7.585000
# 2010-01-05  113.629997    7.699643  28.495001  113.680000    7.616071
# 2010-01-06  113.709999    7.686786  28.219999  113.989998    7.526786
# 2010-01-07  114.190002    7.571429  28.184999  114.330002    7.466071
# 2010-01-08  114.570000    7.571429  27.820000  114.620003    7.466429
# ...                ...         ...        ...         ...         ...
# 2022-12-23  382.910004  132.419998  63.869999  383.059998  129.639999
# 2022-12-27  381.399994  131.410004  64.290001  383.149994  128.720001
# 2022-12-28  376.660004  131.029999  64.650002  383.390015  125.870003
# 2022-12-29  383.440002  130.479996  64.150002  384.350006  127.730003
# 2022-12-30  382.429993  129.949997  63.919998  382.579987  127.430000
#
#                                          Open                         \
#                    KO         SPY        AAPL         KO         SPY
# Date
# 2010-01-04  28.450001  111.510002    7.622500  28.580000  112.370003
# 2010-01-05  28.070000  112.849998    7.664286  28.424999  113.260002
# 2010-01-06  27.990000  113.430000    7.656429  28.174999  113.519997
# 2010-01-07  27.875000  113.180000    7.562500  28.165001  113.500000
# 2010-01-08  27.375000  113.660004    7.510714  27.730000  113.889999
# ...               ...         ...         ...        ...         ...
# 2022-12-23  63.200001  378.029999  130.919998  63.500000  379.649994
# 2022-12-27  63.709999  379.649994  131.380005  63.930000  382.790009
# 2022-12-28  63.490002  376.420013  129.669998  64.459999  381.329987
# 2022-12-29  63.700001  379.079987  127.989998  63.799999  379.630005
# 2022-12-30  63.169998  378.429993  128.410004  63.919998  380.640015
#
#                Volume
#                  AAPL        KO        SPY
# Date
# 2010-01-04  493729600  13870400  118944600
# 2010-01-05  601904800  23172400  111579900
# 2010-01-06  552160000  19264600  116074400
# 2010-01-07  477131200  13234600  131091100
# 2010-01-08  447610800  28712400  126402800
# ...               ...       ...        ...
# 2022-12-23   63814900   6463300   59857300
# 2022-12-27   69007800   7320700   51638200
# 2022-12-28   85438400   7159400   70911500
# 2022-12-29   75703700   7169300   66970900
# 2022-12-30   77034200   7650200   84022200
#
# [3272 rows x 18 columns]

# %%
stocks = pd.read_csv("stockstest.csv", header = [0,1], index_col=[0], parse_dates = [0])

# %%
stocks
# Out:
#              Adj Close                              Close             \
#                   AAPL         KO         SPY        AAPL         KO
# Date
# 2010-01-04    6.487533  18.645304   87.483215    7.643214  28.520000
# 2010-01-05    6.498750  18.419765   87.714775    7.656429  28.174999
# 2010-01-06    6.395379  18.413221   87.776535    7.534643  28.165001
# 2010-01-07    6.383556  18.367462   88.147087    7.520714  28.094999
# 2010-01-08    6.425995  18.027510   88.440392    7.570714  27.575001
# ...                ...        ...         ...         ...        ...
# 2022-12-23  131.299820  62.360737  378.706665  131.860001  63.820000
# 2022-12-27  129.477585  62.741817  377.213226  130.029999  64.209999
# 2022-12-28  125.504539  62.116451  372.525269  126.040001  63.570000
# 2022-12-29  129.059372  62.487762  379.230835  129.610001  63.950001
# 2022-12-30  129.378006  62.155540  378.231934  129.929993  63.610001
#
#                               High                                Low  \
#                    SPY        AAPL         KO         SPY        AAPL
# Date
# 2010-01-04  113.330002    7.660714  28.610001  113.389999    7.585000
# 2010-01-05  113.629997    7.699643  28.495001  113.680000    7.616071
# 2010-01-06  113.709999    7.686786  28.219999  113.989998    7.526786
# 2010-01-07  114.190002    7.571429  28.184999  114.330002    7.466071
# 2010-01-08  114.570000    7.571429  27.820000  114.620003    7.466429
# ...                ...         ...        ...         ...         ...
# 2022-12-23  382.910004  132.419998  63.869999  383.059998  129.639999
# 2022-12-27  381.399994  131.410004  64.290001  383.149994  128.720001
# 2022-12-28  376.660004  131.029999  64.650002  383.390015  125.870003
# 2022-12-29  383.440002  130.479996  64.150002  384.350006  127.730003
# 2022-12-30  382.429993  129.949997  63.919998  382.579987  127.430000
#
#                                          Open                         \
#                    KO         SPY        AAPL         KO         SPY
# Date
# 2010-01-04  28.450001  111.510002    7.622500  28.580000  112.370003
# 2010-01-05  28.070000  112.849998    7.664286  28.424999  113.260002
# 2010-01-06  27.990000  113.430000    7.656429  28.174999  113.519997
# 2010-01-07  27.875000  113.180000    7.562500  28.165001  113.500000
# 2010-01-08  27.375000  113.660004    7.510714  27.730000  113.889999
# ...               ...         ...         ...        ...         ...
# 2022-12-23  63.200001  378.029999  130.919998  63.500000  379.649994
# 2022-12-27  63.709999  379.649994  131.380005  63.930000  382.790009
# 2022-12-28  63.490002  376.420013  129.669998  64.459999  381.329987
# 2022-12-29  63.700001  379.079987  127.989998  63.799999  379.630005
# 2022-12-30  63.169998  378.429993  128.410004  63.919998  380.640015
#
#                Volume
#                  AAPL        KO        SPY
# Date
# 2010-01-04  493729600  13870400  118944600
# 2010-01-05  601904800  23172400  111579900
# 2010-01-06  552160000  19264600  116074400
# 2010-01-07  477131200  13234600  131091100
# 2010-01-08  447610800  28712400  126402800
# ...               ...       ...        ...
# 2022-12-23   63814900   6463300   59857300
# 2022-12-27   69007800   7320700   51638200
# 2022-12-28   85438400   7159400   70911500
# 2022-12-29   75703700   7169300   66970900
# 2022-12-30   77034200   7650200   84022200
#
# [3272 rows x 18 columns]

# %%
parse_dates
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 parse_dates
#
# NameError: name 'parse_dates' is not defined

# %%
# convert multi index to one tuple

# %%
stocks.columns = stocks.columns.to_flat_index()

# %%
stocks.columns

# %%
stocks

# %%
stocks.columns = pd.MultiIndex.from_tuples(stocks.columns)

# %%
stocks

# %%
stocks.describe()

# %%
stocks.loc[:,"Close"]

# %%
close = stocks.loc[:,"Close"].copy()

# %%
close

# %%
# %matplotlib inline

# %%
# %matplotlib inline
plt.style.use("seaborn")

# %%
# %matplotlib inline
plt.style.use("seaborn-v0_8-<style>")

# %%
# %matplotlib inline
plt.style.use("bmh")

# %%
close.plot(figsize=(15,8),fonts=12)

# %%
close.plot(figsize=(15,8),fontsize=12)
plt.legend(fontsize=12)
plt.show

# %%
close.plot(figsize=(15,8),fontsize=12)

# %%
close.plot(figsize=(15,8),fontsize=12)
plt.legend(fontsize=12)
plt.show

# %%
close.iloc[0,0]

# %%
close.AAPL

# %%
close.AAPL.div(close.iloc[0,0])

# %%
close.AAPL.div(close.iloc[0,0]).mul(100)

# %%
close.AAPL.div(close.iloc[0,0]).mul(100)

# %%
close.div(close.iloc[0]).mul(100)

# %%
normclose=close.div(close.iloc[0]).mul(100)

# %%
normclose.plot(figsize=(15,8),fontsize=12)
plt.legend(fontsize=12)
plt.show

# %%
normclose.plot(figsize=(15,8),fontsize=12)
plt.legend(fontsize=12)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
aapl = close.AAPL.copy().to_frame()

# %%
aapl
# Out:
#                   AAPL
# Date
# 2010-01-04    7.643214
# 2010-01-05    7.656429
# 2010-01-06    7.534643
# 2010-01-07    7.520714
# 2010-01-08    7.570714
# ...                ...
# 2022-12-23  131.860001
# 2022-12-27  130.029999
# 2022-12-28  126.040001
# 2022-12-29  129.610001
# 2022-12-30  129.929993
#
# [3272 rows x 1 columns]

# %%
aapl.shift(peroids = 1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[79], line 1
# ----> 1 aapl.shift(peroids = 1)
#
# TypeError: DataFrame.shift() got an unexpected keyword argument 'peroids'

# %%
aapl.shift(periods = 1)
# Out:
#                   AAPL
# Date
# 2010-01-04         NaN
# 2010-01-05    7.643214
# 2010-01-06    7.656429
# 2010-01-07    7.534643
# 2010-01-08    7.520714
# ...                ...
# 2022-12-23  132.229996
# 2022-12-27  131.860001
# 2022-12-28  130.029999
# 2022-12-29  126.040001
# 2022-12-30  129.610001
#
# [3272 rows x 1 columns]

# %%
aapl["lag1"]=aapl.shift(periods = 1)

# %%
aapl
# Out:
#                   AAPL        lag1
# Date
# 2010-01-04    7.643214         NaN
# 2010-01-05    7.656429    7.643214
# 2010-01-06    7.534643    7.656429
# 2010-01-07    7.520714    7.534643
# 2010-01-08    7.570714    7.520714
# ...                ...         ...
# 2022-12-23  131.860001  132.229996
# 2022-12-27  130.029999  131.860001
# 2022-12-28  126.040001  130.029999
# 2022-12-29  129.610001  126.040001
# 2022-12-30  129.929993  129.610001
#
# [3272 rows x 2 columns]

# %%
aapl.AAPL.sub(aapl.lag1)
# Out:
# Date
# 2010-01-04         NaN
# 2010-01-05    0.013215
# 2010-01-06   -0.121786
# 2010-01-07   -0.013929
# 2010-01-08    0.050000
#                 ...
# 2022-12-23   -0.369995
# 2022-12-27   -1.830002
# 2022-12-28   -3.989998
# 2022-12-29    3.570000
# 2022-12-30    0.319992
# Length: 3272, dtype: float64

# %%
aapl["Diff"] = aapl.AAPL.sub(aapl.lag1)

# %%
aapl
# Out:
#                   AAPL        lag1      Diff
# Date
# 2010-01-04    7.643214         NaN       NaN
# 2010-01-05    7.656429    7.643214  0.013215
# 2010-01-06    7.534643    7.656429 -0.121786
# 2010-01-07    7.520714    7.534643 -0.013929
# 2010-01-08    7.570714    7.520714  0.050000
# ...                ...         ...       ...
# 2022-12-23  131.860001  132.229996 -0.369995
# 2022-12-27  130.029999  131.860001 -1.830002
# 2022-12-28  126.040001  130.029999 -3.989998
# 2022-12-29  129.610001  126.040001  3.570000
# 2022-12-30  129.929993  129.610001  0.319992
#
# [3272 rows x 3 columns]

# %%
aapl.AAPL.div(aapl.lag1)
# Out:
# Date
# 2010-01-04         NaN
# 2010-01-05    1.001729
# 2010-01-06    0.984094
# 2010-01-07    0.998151
# 2010-01-08    1.006648
#                 ...
# 2022-12-23    0.997202
# 2022-12-27    0.986122
# 2022-12-28    0.969315
# 2022-12-29    1.028324
# 2022-12-30    1.002469
# Length: 3272, dtype: float64

# %%
aapl["% Change"] = aapl.AAPL.div(aapl.lag1).sub(1).mul(100)

# %%
aapl
# Out:
#                   AAPL        lag1      Diff  % Change
# Date
# 2010-01-04    7.643214         NaN       NaN       NaN
# 2010-01-05    7.656429    7.643214  0.013215  1.001729
# 2010-01-06    7.534643    7.656429 -0.121786  0.984094
# 2010-01-07    7.520714    7.534643 -0.013929  0.998151
# 2010-01-08    7.570714    7.520714  0.050000  1.006648
# ...                ...         ...       ...       ...
# 2022-12-23  131.860001  132.229996 -0.369995  0.997202
# 2022-12-27  130.029999  131.860001 -1.830002  0.986122
# 2022-12-28  126.040001  130.029999 -3.989998  0.969315
# 2022-12-29  129.610001  126.040001  3.570000  1.028324
# 2022-12-30  129.929993  129.610001  0.319992  1.002469
#
# [3272 rows x 4 columns]

# %%
aapl["Diff2"]=aapl.AAPL.diff(periods=1)

# %%
aapl
# Out:
#                   AAPL        lag1      Diff  % Change     Diff2
# Date
# 2010-01-04    7.643214         NaN       NaN       NaN       NaN
# 2010-01-05    7.656429    7.643214  0.013215  1.001729  0.013215
# 2010-01-06    7.534643    7.656429 -0.121786  0.984094 -0.121786
# 2010-01-07    7.520714    7.534643 -0.013929  0.998151 -0.013929
# 2010-01-08    7.570714    7.520714  0.050000  1.006648  0.050000
# ...                ...         ...       ...       ...       ...
# 2022-12-23  131.860001  132.229996 -0.369995  0.997202 -0.369995
# 2022-12-27  130.029999  131.860001 -1.830002  0.986122 -1.830002
# 2022-12-28  126.040001  130.029999 -3.989998  0.969315 -3.989998
# 2022-12-29  129.610001  126.040001  3.570000  1.028324  3.570000
# 2022-12-30  129.929993  129.610001  0.319992  1.002469  0.319992
#
# [3272 rows x 5 columns]

# %%
aapl["% Change 2"] = aapl.AAPL.pct_change(peroids=1).mul(100)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[91], line 1
# ----> 1 aapl["% Change 2"] = aapl.AAPL.pct_change(peroids=1).mul(100)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:10957, in NDFrame.pct_change(self, periods, fill_method, limit, freq, **kwargs)
#   10954     assert _data is not None  # needed for mypy
#   10955     data = _data
# > 10957 shifted = data.shift(periods=periods, freq=freq, axis=axis, **kwargs)
#   10958 # Unsupported left operand type for / ("NDFrameT")
#   10959 rs = data / shifted - 1  # type: ignore[operator]
#
# TypeError: Series.shift() got an unexpected keyword argument 'peroids'

# %%
aapl
# Out:
#                   AAPL        lag1      Diff  % Change     Diff2
# Date
# 2010-01-04    7.643214         NaN       NaN       NaN       NaN
# 2010-01-05    7.656429    7.643214  0.013215  1.001729  0.013215
# 2010-01-06    7.534643    7.656429 -0.121786  0.984094 -0.121786
# 2010-01-07    7.520714    7.534643 -0.013929  0.998151 -0.013929
# 2010-01-08    7.570714    7.520714  0.050000  1.006648  0.050000
# ...                ...         ...       ...       ...       ...
# 2022-12-23  131.860001  132.229996 -0.369995  0.997202 -0.369995
# 2022-12-27  130.029999  131.860001 -1.830002  0.986122 -1.830002
# 2022-12-28  126.040001  130.029999 -3.989998  0.969315 -3.989998
# 2022-12-29  129.610001  126.040001  3.570000  1.028324  3.570000
# 2022-12-30  129.929993  129.610001  0.319992  1.002469  0.319992
#
# [3272 rows x 5 columns]

# %%
aapl["% Change 2"] = aapl.AAPL.pct_change(periods=1).mul(100)

# %%
aapl
# Out:
#                   AAPL        lag1      Diff  % Change     Diff2  % Change 2
# Date
# 2010-01-04    7.643214         NaN       NaN       NaN       NaN         NaN
# 2010-01-05    7.656429    7.643214  0.013215  1.001729  0.013215    0.172893
# 2010-01-06    7.534643    7.656429 -0.121786  0.984094 -0.121786   -1.590632
# 2010-01-07    7.520714    7.534643 -0.013929  0.998151 -0.013929   -0.184871
# 2010-01-08    7.570714    7.520714  0.050000  1.006648  0.050000    0.664833
# ...                ...         ...       ...       ...       ...         ...
# 2022-12-23  131.860001  132.229996 -0.369995  0.997202 -0.369995   -0.279812
# 2022-12-27  130.029999  131.860001 -1.830002  0.986122 -1.830002   -1.387837
# 2022-12-28  126.040001  130.029999 -3.989998  0.969315 -3.989998   -3.068521
# 2022-12-29  129.610001  126.040001  3.570000  1.028324  3.570000    2.832434
# 2022-12-30  129.929993  129.610001  0.319992  1.002469  0.319992    0.246888
#
# [3272 rows x 6 columns]

# %%
aapl
# Out:
#                   AAPL        lag1      Diff  % Change     Diff2  % Change 2
# Date
# 2010-01-04    7.643214         NaN       NaN       NaN       NaN         NaN
# 2010-01-05    7.656429    7.643214  0.013215  1.001729  0.013215    0.172893
# 2010-01-06    7.534643    7.656429 -0.121786  0.984094 -0.121786   -1.590632
# 2010-01-07    7.520714    7.534643 -0.013929  0.998151 -0.013929   -0.184871
# 2010-01-08    7.570714    7.520714  0.050000  1.006648  0.050000    0.664833
# ...                ...         ...       ...       ...       ...         ...
# 2022-12-23  131.860001  132.229996 -0.369995  0.997202 -0.369995   -0.279812
# 2022-12-27  130.029999  131.860001 -1.830002  0.986122 -1.830002   -1.387837
# 2022-12-28  126.040001  130.029999 -3.989998  0.969315 -3.989998   -3.068521
# 2022-12-29  129.610001  126.040001  3.570000  1.028324  3.570000    2.832434
# 2022-12-30  129.929993  129.610001  0.319992  1.002469  0.319992    0.246888
#
# [3272 rows x 6 columns]

# %%
aapl
# Out:
#                   AAPL        lag1      Diff  % Change     Diff2  % Change 2
# Date
# 2010-01-04    7.643214         NaN       NaN       NaN       NaN         NaN
# 2010-01-05    7.656429    7.643214  0.013215  0.172893  0.013215    0.172893
# 2010-01-06    7.534643    7.656429 -0.121786 -1.590632 -0.121786   -1.590632
# 2010-01-07    7.520714    7.534643 -0.013929 -0.184871 -0.013929   -0.184871
# 2010-01-08    7.570714    7.520714  0.050000  0.664833  0.050000    0.664833
# ...                ...         ...       ...       ...       ...         ...
# 2022-12-23  131.860001  132.229996 -0.369995 -0.279812 -0.369995   -0.279812
# 2022-12-27  130.029999  131.860001 -1.830002 -1.387837 -1.830002   -1.387837
# 2022-12-28  126.040001  130.029999 -3.989998 -3.068521 -3.989998   -3.068521
# 2022-12-29  129.610001  126.040001  3.570000  2.832434  3.570000    2.832434
# 2022-12-30  129.929993  129.610001  0.319992  0.246888  0.319992    0.246888
#
# [3272 rows x 6 columns]

# %%
del aapl["% Change"]

# %%
aapl.rename(columns = {'% Change 2':'Change'}, inplace = True)

# %%
aapl
# Out:
#                   AAPL      Diff    Change
# Date
# 2010-01-04    7.643214       NaN       NaN
# 2010-01-05    7.656429  0.013215  0.172893
# 2010-01-06    7.534643 -0.121786 -1.590632
# 2010-01-07    7.520714 -0.013929 -0.184871
# 2010-01-08    7.570714  0.050000  0.664833
# ...                ...       ...       ...
# 2022-12-23  131.860001 -0.369995 -0.279812
# 2022-12-27  130.029999 -1.830002 -1.387837
# 2022-12-28  126.040001 -3.989998 -3.068521
# 2022-12-29  129.610001  3.570000  2.832434
# 2022-12-30  129.929993  0.319992  0.246888
#
# [3272 rows x 3 columns]

# %%
aapl.AAPL.resample("BM").last().pct_change(periods=1).mul(100)
# Out:
# Date
# 2010-01-29          NaN
# 2010-02-26     6.539620
# 2010-03-31    14.847028
# 2010-04-30    11.102138
# 2010-05-31    -1.612472
#                 ...
# 2022-08-31    -3.255180
# 2022-09-30   -12.097700
# 2022-10-31    10.955137
# 2022-11-30    -3.462891
# 2022-12-30   -12.227255
# Freq: BM, Name: AAPL, Length: 156, dtype: float64

# %%
del aapl["Change"]

# %%
ret = aapl.pct_change().dropna()

# %%
ret
# Out:
#                 AAPL       Diff
# Date
# 2010-01-06 -0.015906 -10.216000
# 2010-01-07 -0.001849  -0.885624
# 2010-01-08  0.006648  -4.589552
# 2010-01-11 -0.008821  -2.335692
# 2010-01-12 -0.011375   0.278106
# ...              ...        ...
# 2022-12-23 -0.002798  -0.885095
# 2022-12-27 -0.013878   3.946016
# 2022-12-28 -0.030685   1.180325
# 2022-12-29  0.028324  -1.894737
# 2022-12-30  0.002469  -0.910366
#
# [3270 rows x 2 columns]

# %%
del aapl["Diff"]

# %%
ret
# Out:
#                 AAPL       Diff
# Date
# 2010-01-06 -0.015906 -10.216000
# 2010-01-07 -0.001849  -0.885624
# 2010-01-08  0.006648  -4.589552
# 2010-01-11 -0.008821  -2.335692
# 2010-01-12 -0.011375   0.278106
# ...              ...        ...
# 2022-12-23 -0.002798  -0.885095
# 2022-12-27 -0.013878   3.946016
# 2022-12-28 -0.030685   1.180325
# 2022-12-29  0.028324  -1.894737
# 2022-12-30  0.002469  -0.910366
#
# [3270 rows x 2 columns]

# %%
del ret["Diff"]

# %%
ret
# Out:
#                 AAPL
# Date
# 2010-01-06 -0.015906
# 2010-01-07 -0.001849
# 2010-01-08  0.006648
# 2010-01-11 -0.008821
# 2010-01-12 -0.011375
# ...              ...
# 2022-12-23 -0.002798
# 2022-12-27 -0.013878
# 2022-12-28 -0.030685
# 2022-12-29  0.028324
# 2022-12-30  0.002469
#
# [3270 rows x 1 columns]

# %%
ret.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3270 entries, 2010-01-06 to 2022-12-30
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AAPL    3270 non-null   float64
# dtypes: float64(1)
# memory usage: 51.1 KB

# %%
ret.plot(kind="hist",figsize=(12,8), bins=100)
plt.show()

# %%
daily_mean_ret=ret.mean()

# %%
var_daily=ret.var()

# %%
var_daily
# Out:
# AAPL    0.000328
# dtype: float64

# %%
std_daily= np.sqrt(var_daily)

# %%
std_daily
# Out:
# AAPL    0.018102
# dtype: float64

# %%
ret.std()
# Out:
# AAPL    0.018102
# dtype: float64

# %%
annual_mean_ret=daily_mean_ret*252

# %%
annual_mean_ret
# Out:
# AAPL    0.259609
# dtype: float64

# %%
annual_var_return=var_daily*252
annual_var_return
# Out:
# AAPL    0.082576
# dtype: float64

# %%
annual_std_returns= np.sqrt(annual_var_return)

# %%
annual_std_returns
# Out:
# AAPL    0.287361
# dtype: float64

# %%
ret.std()*np.sqrt(252)
# Out:
# AAPL    0.287361
# dtype: float64

# %%
ticker = ["SPY","AAPL","KO","IBM","TSLA","TTD","DIS"]

# %%
stocks = yf.download(ticker, start = "2010-01-01", end = "2023-01-01")
# Out:
# [*********************100%%**********************]  7 of 7 completed

# %%
stocks
# Out:
#              Adj Close                                                \
#                   AAPL        DIS         IBM         KO         SPY
# Date
# 2010-01-04    6.487534  27.933922   78.345871  18.645306   87.483223
# 2010-01-05    6.498749  27.864239   77.399452  18.419754   87.714760
# 2010-01-06    6.395379  27.716164   76.896675  18.413221   87.776543
# 2010-01-07    6.383556  27.724873   76.630501  18.367464   88.147072
# 2010-01-08    6.425996  27.768425   77.399452  18.027502   88.440399
# ...                ...        ...         ...        ...         ...
# 2022-12-23  131.299820  88.010002  136.478241  62.360741  378.706635
# 2022-12-27  129.477585  86.370003  137.220139  62.741817  377.213196
# 2022-12-28  125.504539  84.169998  134.907776  62.116455  372.525238
# 2022-12-29  129.059372  87.180000  135.909790  62.487762  379.230835
# 2022-12-30  129.378006  86.879997  135.746002  62.155540  378.231934
#
#                                         Close                         ...  \
#                   TSLA        TTD        AAPL        DIS         IBM  ...
# Date                                                                  ...
# 2010-01-04         NaN        NaN    7.643214  32.070000  126.625237  ...
# 2010-01-05         NaN        NaN    7.656429  31.990000  125.095604  ...
# 2010-01-06         NaN        NaN    7.534643  31.820000  124.282982  ...
# 2010-01-07         NaN        NaN    7.520714  31.830000  123.852776  ...
# 2010-01-08         NaN        NaN    7.570714  31.879999  125.095604  ...
# ...                ...        ...         ...        ...         ...  ...
# 2022-12-23  123.150002  44.880001  131.860001  88.010002  141.649994  ...
# 2022-12-27  109.099998  43.820000  130.029999  86.370003  142.419998  ...
# 2022-12-28  112.709999  43.320000  126.040001  84.169998  140.020004  ...
# 2022-12-29  121.820000  45.340000  129.610001  87.180000  141.059998  ...
# 2022-12-30  123.180000  44.830002  129.929993  86.879997  140.889999  ...
#
#                   Open                            Volume                     \
#                    SPY        TSLA        TTD       AAPL       DIS      IBM
# Date
# 2010-01-04  112.370003         NaN        NaN  493729600  13700400  6438444
# 2010-01-05  113.260002         NaN        NaN  601904800  10307700  7156104
# 2010-01-06  113.519997         NaN        NaN  552160000  10709500  5863144
# 2010-01-07  113.500000         NaN        NaN  477131200   8202100  6109268
# 2010-01-08  113.889999         NaN        NaN  447610800   7657500  4390271
# ...                ...         ...        ...        ...       ...      ...
# 2022-12-23  379.649994  126.370003  44.500000   63814900  11171600  2092500
# 2022-12-27  382.790009  117.500000  44.450001   69007800  11561400  2742400
# 2022-12-28  381.329987  110.349998  43.709999   85438400  12399500  2539500
# 2022-12-29  379.630005  120.389999  44.299999   75703700  13045100  2337200
# 2022-12-30  380.640015  119.949997  44.020000   77034200  23231000  2858000
#
#
#                   KO        SPY         TSLA        TTD
# Date
# 2010-01-04  13870400  118944600          NaN        NaN
# 2010-01-05  23172400  111579900          NaN        NaN
# 2010-01-06  19264600  116074400          NaN        NaN
# 2010-01-07  13234600  131091100          NaN        NaN
# 2010-01-08  28712400  126402800          NaN        NaN
# ...              ...        ...          ...        ...
# 2022-12-23   6463300   59857300  166989700.0  2421700.0
# 2022-12-27   7320700   51638200  208643400.0  2639400.0
# 2022-12-28   7159400   70911500  221070500.0  2766500.0
# 2022-12-29   7169300   66970900  221923300.0  2946300.0
# 2022-12-30   7650200   84022200  157777300.0  3110400.0
#
# [3272 rows x 42 columns]

# %%
close = stocks.loc[:,"Close"].copy()

# %%
normclose=close.div(close.iloc[0]).mul(100)

# %%
normclose.plot(figsize=(15,8),fontsize=12)
plt.legend(fontsize=12)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
close = stocks.loc[:,"Close"].copy()

# %%
ticker = ["SPY","AAPL","KO","IBM","TSLA","TTD","DIS","MSFT"]
stocks = yf.download(ticker, start = "2010-01-01", end = "2023-01-01")
close = stocks.loc[:,"Close"].copy()
normclose=close.div(close.iloc[0]).mul(100)
normclose.plot(figsize=(15,8),fontsize=12)
plt.legend(fontsize=12)
plt.show
# Out:
# [*********************100%%**********************]  8 of 8 completed
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
TTD
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[142], line 1
# ----> 1 TTD
#
# NameError: name 'TTD' is not defined

# %%
ticker
# Out:
# ['SPY', 'AAPL', 'KO', 'IBM', 'TSLA', 'TTD', 'DIS', 'MSFT']

# %%
stocks
# Out:
#              Adj Close                                                \
#                   AAPL        DIS         IBM         KO        MSFT
# Date
# 2010-01-04    6.487533  27.933924   78.345863  18.645308   23.522568
# 2010-01-05    6.498750  27.864239   77.399452  18.419765   23.530159
# 2010-01-06    6.395378  27.716166   76.896690  18.413223   23.385759
# 2010-01-07    6.383556  27.724874   76.630478  18.367468   23.142559
# 2010-01-08    6.425995  27.768425   77.399452  18.027502   23.302160
# ...                ...        ...         ...        ...         ...
# 2022-12-23  131.299820  88.010002  136.478256  62.360741  237.112091
# 2022-12-27  129.477585  86.370003  137.220154  62.741817  235.354095
# 2022-12-28  125.504539  84.169998  134.907791  62.116455  232.940552
# 2022-12-29  129.059372  87.180000  135.909805  62.487762  239.376633
# 2022-12-30  129.378006  86.879997  135.746002  62.155540  238.194702
#
#                                                     Close             ...  \
#                    SPY        TSLA        TTD        AAPL        DIS  ...
# Date                                                                  ...
# 2010-01-04   87.483192         NaN        NaN    7.643214  32.070000  ...
# 2010-01-05   87.714760         NaN        NaN    7.656429  31.990000  ...
# 2010-01-06   87.776558         NaN        NaN    7.534643  31.820000  ...
# 2010-01-07   88.147072         NaN        NaN    7.520714  31.830000  ...
# 2010-01-08   88.440399         NaN        NaN    7.570714  31.879999  ...
# ...                ...         ...        ...         ...        ...  ...
# 2022-12-23  378.706665  123.150002  44.880001  131.860001  88.010002  ...
# 2022-12-27  377.213226  109.099998  43.820000  130.029999  86.370003  ...
# 2022-12-28  372.525269  112.709999  43.320000  126.040001  84.169998  ...
# 2022-12-29  379.230835  121.820000  45.340000  129.610001  87.180000  ...
# 2022-12-30  378.231934  123.180000  44.830002  129.929993  86.879997  ...
#
#                   Open                Volume                               \
#                   TSLA        TTD       AAPL       DIS      IBM        KO
# Date
# 2010-01-04         NaN        NaN  493729600  13700400  6438444  13870400
# 2010-01-05         NaN        NaN  601904800  10307700  7156104  23172400
# 2010-01-06         NaN        NaN  552160000  10709500  5863144  19264600
# 2010-01-07         NaN        NaN  477131200   8202100  6109268  13234600
# 2010-01-08         NaN        NaN  447610800   7657500  4390271  28712400
# ...                ...        ...        ...       ...      ...       ...
# 2022-12-23  126.370003  44.500000   63814900  11171600  2092500   6463300
# 2022-12-27  117.500000  44.450001   69007800  11561400  2742400   7320700
# 2022-12-28  110.349998  43.709999   85438400  12399500  2539500   7159400
# 2022-12-29  120.389999  44.299999   75703700  13045100  2337200   7169300
# 2022-12-30  119.949997  44.020000   77034200  23231000  2858000   7650200
#
#
#                 MSFT        SPY         TSLA        TTD
# Date
# 2010-01-04  38409100  118944600          NaN        NaN
# 2010-01-05  49749600  111579900          NaN        NaN
# 2010-01-06  58182400  116074400          NaN        NaN
# 2010-01-07  50559700  131091100          NaN        NaN
# 2010-01-08  51197400  126402800          NaN        NaN
# ...              ...        ...          ...        ...
# 2022-12-23  21207000   59857300  166989700.0  2421700.0
# 2022-12-27  16688600   51638200  208643400.0  2639400.0
# 2022-12-28  17457100   70911500  221070500.0  2766500.0
# 2022-12-29  19770700   66970900  221923300.0  2946300.0
# 2022-12-30  21938500   84022200  157777300.0  3110400.0
#
# [3272 rows x 48 columns]

# %%
ticker = ["SPY","AAPL","KO","IBM","TSLA","TTD","DIS","MSFT"]
stocks = yf.download(ticker, start = "2020-01-01", end = "2023-01-01")
close = stocks.loc[:,"Close"].copy()
normclose=close.div(close.iloc[0]).mul(100)
normclose.plot(figsize=(15,8),fontsize=12)
plt.legend(fontsize=12)
plt.show
# Out:
# [*********************100%%**********************]  8 of 8 completed
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
ret=close.pct_change.dropna()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[146], line 1
# ----> 1 re=close.pct_change.dropna()
#
# AttributeError: 'function' object has no attribute 'dropna'

# %%
ret=close.pct_change().dropna()
ret.head()
# Out:
#                 AAPL       DIS       IBM        KO      MSFT       SPY  \
# Date
# 2020-01-03 -0.009722 -0.011471 -0.007975 -0.005456 -0.012452 -0.007572
# 2020-01-06  0.007968 -0.005802 -0.001787 -0.000366  0.002585  0.003815
# 2020-01-07 -0.004703  0.000343  0.000671 -0.007682 -0.009118 -0.002812
# 2020-01-08  0.016086 -0.002059  0.008346  0.001843  0.015928  0.005330
# 2020-01-09  0.021241 -0.003920  0.010568  0.018215  0.012493  0.006781
#
#                 TSLA       TTD
# Date
# 2020-01-03  0.029633  0.001695
# 2020-01-06  0.019255  0.022066
# 2020-01-07  0.038801  0.008528
# 2020-01-08  0.049205  0.017554
# 2020-01-09 -0.021945  0.005049

# %%
summary=ret.describe().T.loc[:,["mean","std"]]

# %%
ret.describe()
# Out:
#              AAPL         DIS         IBM          KO        MSFT         SPY  \
# count  755.000000  755.000000  755.000000  755.000000  755.000000  755.000000
# mean     0.000997   -0.000417    0.000298    0.000314    0.000771    0.000341
# std      0.023268    0.024123    0.019228    0.015534    0.021904    0.015800
# min     -0.128647   -0.131632   -0.128507   -0.096725   -0.147390   -0.109424
# 25%     -0.011103   -0.012389   -0.008217   -0.005862   -0.009685   -0.006677
# 50%      0.000613   -0.001252    0.000656    0.000958    0.000560    0.000854
# 75%      0.014154    0.010626    0.008879    0.007367    0.012255    0.008116
# max      0.119808    0.144123    0.113010    0.064796    0.142169    0.090603
#
#              TSLA         TTD
# count  755.000000  755.000000
# mean     0.002965    0.001870
# std      0.045474    0.049530
# min     -0.210628   -0.259786
# 25%     -0.021480   -0.023779
# 50%      0.001953    0.001707
# 75%      0.024981    0.026504
# max      0.198949    0.362202

# %%
summary
# Out:
#           mean       std
# AAPL  0.000997  0.023268
# DIS  -0.000417  0.024123
# IBM   0.000298  0.019228
# KO    0.000314  0.015534
# MSFT  0.000771  0.021904
# SPY   0.000341  0.015800
# TSLA  0.002965  0.045474
# TTD   0.001870  0.049530

# %%
summary["mean"]=summary["mean"]*252
summary["std"]=summary["std"]*np.sqrt(252)
summary
# Out:
#           mean       std
# AAPL  0.251167  0.369374
# DIS  -0.105138  0.382946
# IBM   0.075133  0.305241
# KO    0.079203  0.246602
# MSFT  0.194285  0.347721
# SPY   0.086058  0.250816
# TSLA  0.747064  0.721882
# TTD   0.471281  0.786271

# %%
summary.plot.scatter(x="std",y="mean",figsize=(12,8),s=50,fontsize=15)
for i in summary.index:
    if i != "KO":
        plt.annotate(i,xy=(summary.loc[i,"std"]+0.003,summary.loc[i,"mean"]+0.003),size=15)

plt.annotate("KO",xy=(summary.loc["KO","std"]+0.003,summary.loc["KO","mean"]-0.03),size=15)
plt.xlabel("Annual risk(std)", fontsize= 15)
plt.ylabel("Annual return", fontsize= 15)
plt.title("Risk/Returen", fontsize = 25)
plt.show()

# %%
ret
# Out:
#                 AAPL       DIS       IBM        KO      MSFT       SPY  \
# Date
# 2020-01-03 -0.009722 -0.011471 -0.007975 -0.005456 -0.012452 -0.007572
# 2020-01-06  0.007968 -0.005802 -0.001787 -0.000366  0.002585  0.003815
# 2020-01-07 -0.004703  0.000343  0.000671 -0.007682 -0.009118 -0.002812
# 2020-01-08  0.016086 -0.002059  0.008346  0.001843  0.015928  0.005330
# 2020-01-09  0.021241 -0.003920  0.010568  0.018215  0.012493  0.006781
# ...              ...       ...       ...       ...       ...       ...
# 2022-12-23 -0.002798  0.015461  0.005466  0.007578  0.002267  0.005752
# 2022-12-27 -0.013878 -0.018634  0.005436  0.006111 -0.007414 -0.003944
# 2022-12-28 -0.030685 -0.025472 -0.016852 -0.009967 -0.010255 -0.012428
# 2022-12-29  0.028324  0.035761  0.007427  0.005978  0.027630  0.018000
# 2022-12-30  0.002469 -0.003441 -0.001205 -0.005317 -0.004938 -0.002634
#
#                 TSLA       TTD
# Date
# 2020-01-03  0.029633  0.001695
# 2020-01-06  0.019255  0.022066
# 2020-01-07  0.038801  0.008528
# 2020-01-08  0.049205  0.017554
# 2020-01-09 -0.021945  0.005049
# ...              ...       ...
# 2022-12-23 -0.017551 -0.000445
# 2022-12-27 -0.114089 -0.023619
# 2022-12-28  0.033089 -0.011410
# 2022-12-29  0.080827  0.046630
# 2022-12-30  0.011164 -0.011248
#
# [755 rows x 8 columns]

# %%
ret.cov()
# Out:
#           AAPL       DIS       IBM        KO      MSFT       SPY      TSLA  \
# AAPL  0.000541  0.000285  0.000207  0.000178  0.000413  0.000303  0.000550
# DIS   0.000285  0.000582  0.000224  0.000200  0.000290  0.000273  0.000389
# IBM   0.000207  0.000224  0.000370  0.000187  0.000203  0.000206  0.000188
# KO    0.000178  0.000200  0.000187  0.000241  0.000173  0.000174  0.000158
# MSFT  0.000413  0.000290  0.000203  0.000173  0.000480  0.000296  0.000498
# SPY   0.000303  0.000273  0.000206  0.000174  0.000296  0.000250  0.000369
# TSLA  0.000550  0.000389  0.000188  0.000158  0.000498  0.000369  0.002068
# TTD   0.000586  0.000517  0.000223  0.000157  0.000607  0.000441  0.001036
#
#            TTD
# AAPL  0.000586
# DIS   0.000517
# IBM   0.000223
# KO    0.000157
# MSFT  0.000607
# SPY   0.000441
# TSLA  0.001036
# TTD   0.002453

# %%
ret.corr()
# Out:
#           AAPL       DIS       IBM        KO      MSFT       SPY      TSLA  \
# AAPL  1.000000  0.507603  0.463380  0.493016  0.811198  0.824885  0.519510
# DIS   0.507603  1.000000  0.482116  0.534371  0.548562  0.715017  0.354516
# IBM   0.463380  0.482116  1.000000  0.624943  0.481091  0.678180  0.215490
# KO    0.493016  0.534371  0.624943  1.000000  0.508676  0.707335  0.224259
# MSFT  0.811198  0.548562  0.481091  0.508676  1.000000  0.856098  0.500395
# SPY   0.824885  0.715017  0.678180  0.707335  0.856098  1.000000  0.513108
# TSLA  0.519510  0.354516  0.215490  0.224259  0.500395  0.513108  1.000000
# TTD   0.508519  0.432368  0.234403  0.203950  0.559840  0.564010  0.459815
#
#            TTD
# AAPL  0.508519
# DIS   0.432368
# IBM   0.234403
# KO    0.203950
# MSFT  0.559840
# SPY   0.564010
# TSLA  0.459815
# TTD   1.000000

# %%
import seaborn as sns

# %%
plt.figure(figsize=(12,8))
sns.set(font_scale=1.4)
sns.heatmap(ret.corr(), cmap="Reds",annot=True,annot_kws={"size":15},vmax=0.6)
plt.show()

# %%
df = pd.DataFrame(index=[2020,2021,2022],data=[100,50,95],columns=["Price"])

# %%
df
# Out:
#       Price
# 2020    100
# 2021     50
# 2022     95

# %%
simplereturns= df.pct_change().dropna()

# %%
simplereturns.mean()
# Out:
# Price    0.2
# dtype: float64

# %%
logreturns=np.log(df/df.shift(1)).dropna()

# %%
logreturns
# Out:
#          Price
# 2021 -0.693147
# 2022  0.641854

# %%
logreturns.mean()
# Out:
# Price   -0.025647
# dtype: float64

# %%
100*np.exp(logreturns.mean()*2)
# Out:
# Price    95.0
# dtype: float64

# %%
SPY = yf.download("SPY")
SPY
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1993-01-29   43.968750   43.968750   43.750000   43.937500   24.941401
# 1993-02-01   43.968750   44.250000   43.968750   44.250000   25.118784
# 1993-02-02   44.218750   44.375000   44.125000   44.343750   25.171999
# 1993-02-03   44.406250   44.843750   44.375000   44.812500   25.438107
# 1993-02-04   44.968750   45.093750   44.468750   45.000000   25.544533
# ...                ...         ...         ...         ...         ...
# 2023-10-05  424.359985  425.369995  421.170013  424.500000  424.500000
# 2023-10-06  421.970001  431.130005  420.600006  429.540009  429.540009
# 2023-10-09  427.579987  432.880005  427.010010  432.290009  432.290009
# 2023-10-10  432.940002  437.220001  432.529999  434.540009  434.540009
# 2023-10-11  435.640015  436.579987  433.179993  436.320007  436.320007
#
#                Volume
# Date
# 1993-01-29    1003200
# 1993-02-01     480500
# 1993-02-02     201300
# 1993-02-03     529400
# 1993-02-04     531500
# ...               ...
# 2023-10-05   70142700
# 2023-10-06  113202700
# 2023-10-09   80374400
# 2023-10-10   78607300
# 2023-10-11   62344800
#
# [7731 rows x 6 columns]

# %%
spy = SPY.Close.to_frame()

# %%
spy
# Out:
# Date
# 1993-01-29     43.937500
# 1993-02-01     44.250000
# 1993-02-02     44.343750
# 1993-02-03     44.812500
# 1993-02-04     45.000000
#                  ...
# 2023-10-05    424.500000
# 2023-10-06    429.540009
# 2023-10-09    432.290009
# 2023-10-10    434.540009
# 2023-10-11    436.320007
# Name: Close, Length: 7731, dtype: float64

# %%
spy.plot(figsize=(12,8),fontsize=15)
plt.legend(loc="upper left", fontsize=15)
plt.show(
)

# %%
spy_roll=spy.rolling(window=10)

# %%
spy_roll=spy_roll.mean()
spy_roll
# Out:
#                  Close
# Date
# 1993-01-29         NaN
# 1993-02-01         NaN
# 1993-02-02         NaN
# 1993-02-03         NaN
# 1993-02-04         NaN
# ...                ...
# 2023-10-05  426.864001
# 2023-10-06  426.776001
# 2023-10-09  426.782001
# 2023-10-10  427.648001
# 2023-10-11  428.675003
#
# [7731 rows x 1 columns]

# %%
spy_roll.head(15)
# Out:
#                 Close
# Date
# 1993-01-29        NaN
# 1993-02-01        NaN
# 1993-02-02        NaN
# 1993-02-03        NaN
# 1993-02-04        NaN
# 1993-02-05        NaN
# 1993-02-08        NaN
# 1993-02-09        NaN
# 1993-02-10        NaN
# 1993-02-11  44.659375
# 1993-02-12  44.725000
# 1993-02-16  44.646875
# 1993-02-17  44.556250
# 1993-02-18  44.415625
# 1993-02-19  44.271875

# %%
spy.rolling(window=10).median()
# Out:
#                  Close
# Date
# 1993-01-29         NaN
# 1993-02-01         NaN
# 1993-02-02         NaN
# 1993-02-03         NaN
# 1993-02-04         NaN
# ...                ...
# 2023-10-05  426.679993
# 2023-10-06  426.679993
# 2023-10-09  426.679993
# 2023-10-10  427.395004
# 2023-10-11  428.000000
#
# [7731 rows x 1 columns]

# %%
spy.rolling(window=10).max()
# Out:
#                  Close
# Date
# 1993-01-29         NaN
# 1993-02-01         NaN
# 1993-02-02         NaN
# 1993-02-03         NaN
# 1993-02-04         NaN
# ...                ...
# 2023-10-05  432.230011
# 2023-10-06  432.230011
# 2023-10-09  432.290009
# 2023-10-10  434.540009
# 2023-10-11  436.320007
#
# [7731 rows x 1 columns]

# %%
spy.rolling(window=10,min_periods=5).max().head(15)
# Out:
#                Close
# Date
# 1993-01-29       NaN
# 1993-02-01       NaN
# 1993-02-02       NaN
# 1993-02-03       NaN
# 1993-02-04  45.00000
# 1993-02-05  45.00000
# 1993-02-08  45.00000
# 1993-02-09  45.00000
# 1993-02-10  45.00000
# 1993-02-11  45.00000
# 1993-02-12  45.00000
# 1993-02-16  45.00000
# 1993-02-17  45.00000
# 1993-02-18  45.00000
# 1993-02-19  44.96875

# %%
spy["SMA50"]=spy.rolling(window=50,min_periods=50).mean()

# %%
spy.head(52)
# Out:
#                Close     SMA50
# Date
# 1993-01-29  43.93750       NaN
# 1993-02-01  44.25000       NaN
# 1993-02-02  44.34375       NaN
# 1993-02-03  44.81250       NaN
# 1993-02-04  45.00000       NaN
# 1993-02-05  44.96875       NaN
# 1993-02-08  44.96875       NaN
# 1993-02-09  44.65625       NaN
# 1993-02-10  44.71875       NaN
# 1993-02-11  44.93750       NaN
# 1993-02-12  44.59375       NaN
# 1993-02-16  43.46875       NaN
# 1993-02-17  43.43750       NaN
# 1993-02-18  43.40625       NaN
# 1993-02-19  43.56250       NaN
# 1993-02-22  43.71875       NaN
# 1993-02-23  43.68750       NaN
# 1993-02-24  44.25000       NaN
# 1993-02-25  44.34375       NaN
# 1993-02-26  44.40625       NaN
# 1993-03-01  44.28125       NaN
# 1993-03-02  44.93750       NaN
# 1993-03-03  45.12500       NaN
# 1993-03-04  44.87500       NaN
# 1993-03-05  44.75000       NaN
# 1993-03-08  45.75000       NaN
# 1993-03-09  45.59375       NaN
# 1993-03-10  45.68750       NaN
# 1993-03-11  45.56250       NaN
# 1993-03-12  45.09375       NaN
# 1993-03-15  45.31250       NaN
# 1993-03-16  45.31250       NaN
# 1993-03-17  45.03125       NaN
# 1993-03-18  45.31250       NaN
# 1993-03-19  45.03125       NaN
# 1993-03-22  44.78125       NaN
# 1993-03-23  44.87500       NaN
# 1993-03-24  44.87500       NaN
# 1993-03-25  45.15625       NaN
# 1993-03-26  44.90625       NaN
# 1993-03-29  45.09375       NaN
# 1993-03-30  45.21875       NaN
# 1993-03-31  45.18750       NaN
# 1993-04-01  45.03125       NaN
# 1993-04-02  44.09375       NaN
# 1993-04-05  44.31250       NaN
# 1993-04-06  44.18750       NaN
# 1993-04-07  44.34375       NaN
# 1993-04-08  44.28125       NaN
# 1993-04-12  44.90625  44.68750
# 1993-04-13  45.00000  44.70875
# 1993-04-14  44.93750  44.72250

# %%
spy.plot(figsize=(12,8),fontsize=15)
plt.legend(loc="upper left", fontsize=15)
plt.show()

# %%
spy["SMA200"]=spy.Close.rolling(window=200,min_periods=200).mean()
spy
# Out:
#                  Close       SMA50      SMA200
# Date
# 1993-01-29   43.937500         NaN         NaN
# 1993-02-01   44.250000         NaN         NaN
# 1993-02-02   44.343750         NaN         NaN
# 1993-02-03   44.812500         NaN         NaN
# 1993-02-04   45.000000         NaN         NaN
# ...                ...         ...         ...
# 2023-10-05  424.500000  441.940602  419.551701
# 2023-10-06  429.540009  441.481602  419.799301
# 2023-10-09  432.290009  440.989002  420.058051
# 2023-10-10  434.540009  440.524002  420.299601
# 2023-10-11  436.320007  440.120802  420.577601
#
# [7731 rows x 3 columns]

# %%
spy.plot(figsize=(12,8),fontsize=15)
plt.legend(loc="upper left", fontsize=15)
plt.show()

# %%
spy["EMA100"]=spy.Close.ewm(span=100,min_periods=100).mean()

# %%
spy
# Out:
#                  Close       SMA50      SMA200      EMA100
# Date
# 1993-01-29   43.937500         NaN         NaN         NaN
# 1993-02-01   44.250000         NaN         NaN         NaN
# 1993-02-02   44.343750         NaN         NaN         NaN
# 1993-02-03   44.812500         NaN         NaN         NaN
# 1993-02-04   45.000000         NaN         NaN         NaN
# ...                ...         ...         ...         ...
# 2023-10-05  424.500000  441.940602  419.551701  434.458595
# 2023-10-06  429.540009  441.481602  419.799301  434.361198
# 2023-10-09  432.290009  440.989002  420.058051  434.320184
# 2023-10-10  434.540009  440.524002  420.299601  434.324537
# 2023-10-11  436.320007  440.120802  420.577601  434.364051
#
# [7731 rows x 4 columns]

# %%
spy.plot(figsize=(12,8),fontsize=15)
plt.legend(loc="upper left", fontsize=15)
plt.show()

# %%
spy["Day"]=spy.index.day_name()

# %%
spy
# Out:
#                  Close       SMA50      SMA200      EMA100        Day
# Date
# 1993-01-29   43.937500         NaN         NaN         NaN     Friday
# 1993-02-01   44.250000         NaN         NaN         NaN     Monday
# 1993-02-02   44.343750         NaN         NaN         NaN    Tuesday
# 1993-02-03   44.812500         NaN         NaN         NaN  Wednesday
# 1993-02-04   45.000000         NaN         NaN         NaN   Thursday
# ...                ...         ...         ...         ...        ...
# 2023-10-05  424.500000  441.940602  419.551701  434.458595   Thursday
# 2023-10-06  429.540009  441.481602  419.799301  434.361198     Friday
# 2023-10-09  432.290009  440.989002  420.058051  434.320184     Monday
# 2023-10-10  434.540009  440.524002  420.299601  434.324537    Tuesday
# 2023-10-11  436.320007  440.120802  420.577601  434.364051  Wednesday
#
# [7731 rows x 5 columns]

# %%
spy["Quarter"]=spy.index.quarter

# %%
spy
# Out:
#                  Close       SMA50      SMA200      EMA100        Day  Quarter
# Date
# 1993-01-29   43.937500         NaN         NaN         NaN     Friday        1
# 1993-02-01   44.250000         NaN         NaN         NaN     Monday        1
# 1993-02-02   44.343750         NaN         NaN         NaN    Tuesday        1
# 1993-02-03   44.812500         NaN         NaN         NaN  Wednesday        1
# 1993-02-04   45.000000         NaN         NaN         NaN   Thursday        1
# ...                ...         ...         ...         ...        ...      ...
# 2023-10-05  424.500000  441.940602  419.551701  434.458595   Thursday        4
# 2023-10-06  429.540009  441.481602  419.799301  434.361198     Friday        4
# 2023-10-09  432.290009  440.989002  420.058051  434.320184     Monday        4
# 2023-10-10  434.540009  440.524002  420.299601  434.324537    Tuesday        4
# 2023-10-11  436.320007  440.120802  420.577601  434.364051  Wednesday        4
#
# [7731 rows x 6 columns]

# %%
all_days = pd.date_range(start="2010-12-31",end="2022-01-01",freq="D")

# %%
spy
# Out:
#                  Close       SMA50      SMA200      EMA100        Day  Quarter
# Date
# 1993-01-29   43.937500         NaN         NaN         NaN     Friday        1
# 1993-02-01   44.250000         NaN         NaN         NaN     Monday        1
# 1993-02-02   44.343750         NaN         NaN         NaN    Tuesday        1
# 1993-02-03   44.812500         NaN         NaN         NaN  Wednesday        1
# 1993-02-04   45.000000         NaN         NaN         NaN   Thursday        1
# ...                ...         ...         ...         ...        ...      ...
# 2023-10-05  424.500000  441.940602  419.551701  434.458595   Thursday        4
# 2023-10-06  429.540009  441.481602  419.799301  434.361198     Friday        4
# 2023-10-09  432.290009  440.989002  420.058051  434.320184     Monday        4
# 2023-10-10  434.540009  440.524002  420.299601  434.324537    Tuesday        4
# 2023-10-11  436.320007  440.120802  420.577601  434.364051  Wednesday        4
#
# [7731 rows x 6 columns]

# %%
SPY = yf.download("SPY")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
spy= yf.download("SPY")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
spy=spy.to_frame()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[238], line 1
# ----> 1 spy=spy.to_frame()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:5989, in NDFrame.__getattr__(self, name)
#    5982 if (
#    5983     name not in self._internal_names_set
#    5984     and name not in self._metadata
#    5985     and name not in self._accessors
#    5986     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987 ):
#    5988     return self[name]
# -> 5989 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'to_frame'

# %%
spy= ""

# %%
spy= yf.download("SPY")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
spy
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1993-01-29   43.968750   43.968750   43.750000   43.937500   24.941395
# 1993-02-01   43.968750   44.250000   43.968750   44.250000   25.118780
# 1993-02-02   44.218750   44.375000   44.125000   44.343750   25.172009
# 1993-02-03   44.406250   44.843750   44.375000   44.812500   25.438093
# 1993-02-04   44.968750   45.093750   44.468750   45.000000   25.544535
# ...                ...         ...         ...         ...         ...
# 2023-10-06  421.970001  431.130005  420.600006  429.540009  429.540009
# 2023-10-09  427.579987  432.880005  427.010010  432.290009  432.290009
# 2023-10-10  432.940002  437.220001  432.529999  434.540009  434.540009
# 2023-10-11  435.640015  436.579987  433.179993  436.320007  436.320007
# 2023-10-12  436.950012  437.329987  431.239990  433.779999  433.779999
#
#                Volume
# Date
# 1993-01-29    1003200
# 1993-02-01     480500
# 1993-02-02     201300
# 1993-02-03     529400
# 1993-02-04     531500
# ...               ...
# 2023-10-06  113202700
# 2023-10-09   80374400
# 2023-10-10   78607300
# 2023-10-11   62451700
# 2023-10-12   68681573
#
# [7732 rows x 6 columns]

# %%
all_days = pd.date_range(start="2010-12-31",end="2023-01-01",freq="D")
all_days
# Out:
# DatetimeIndex(['2010-12-31', '2011-01-01', '2011-01-02', '2011-01-03',
#                '2011-01-04', '2011-01-05', '2011-01-06', '2011-01-07',
#                '2011-01-08', '2011-01-09',
#                ...
#                '2022-12-23', '2022-12-24', '2022-12-25', '2022-12-26',
#                '2022-12-27', '2022-12-28', '2022-12-29', '2022-12-30',
#                '2022-12-31', '2023-01-01'],
#               dtype='datetime64[ns]', length=4385, freq='D')

# %%
spy
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1993-01-29   43.968750   43.968750   43.750000   43.937500   24.941395
# 1993-02-01   43.968750   44.250000   43.968750   44.250000   25.118780
# 1993-02-02   44.218750   44.375000   44.125000   44.343750   25.172009
# 1993-02-03   44.406250   44.843750   44.375000   44.812500   25.438093
# 1993-02-04   44.968750   45.093750   44.468750   45.000000   25.544535
# ...                ...         ...         ...         ...         ...
# 2023-10-06  421.970001  431.130005  420.600006  429.540009  429.540009
# 2023-10-09  427.579987  432.880005  427.010010  432.290009  432.290009
# 2023-10-10  432.940002  437.220001  432.529999  434.540009  434.540009
# 2023-10-11  435.640015  436.579987  433.179993  436.320007  436.320007
# 2023-10-12  436.950012  437.329987  431.239990  433.779999  433.779999
#
#                Volume
# Date
# 1993-01-29    1003200
# 1993-02-01     480500
# 1993-02-02     201300
# 1993-02-03     529400
# 1993-02-04     531500
# ...               ...
# 2023-10-06  113202700
# 2023-10-09   80374400
# 2023-10-10   78607300
# 2023-10-11   62451700
# 2023-10-12   68681573
#
# [7732 rows x 6 columns]

# %%
spy=spy.reindex(all_days)

# %%
spy
# Out:
#                   Open        High         Low       Close   Adj Close  \
# 2010-12-31  125.529999  125.870003  125.330002  125.750000   98.976181
# 2011-01-01         NaN         NaN         NaN         NaN         NaN
# 2011-01-02         NaN         NaN         NaN         NaN         NaN
# 2011-01-03  126.709999  127.599998  125.699997  127.050003   99.999397
# 2011-01-04  127.330002  127.370003  126.190002  126.980003   99.944298
# ...                ...         ...         ...         ...         ...
# 2022-12-28  381.329987  383.390015  376.420013  376.660004  372.525269
# 2022-12-29  379.630005  384.350006  379.079987  383.440002  379.230804
# 2022-12-30  380.640015  382.579987  378.429993  382.429993  378.231903
# 2022-12-31         NaN         NaN         NaN         NaN         NaN
# 2023-01-01         NaN         NaN         NaN         NaN         NaN
#
#                  Volume
# 2010-12-31   91218900.0
# 2011-01-01          NaN
# 2011-01-02          NaN
# 2011-01-03  138725200.0
# 2011-01-04  137409700.0
# ...                 ...
# 2022-12-28   70911500.0
# 2022-12-29   66970900.0
# 2022-12-30   84022200.0
# 2022-12-31          NaN
# 2023-01-01          NaN
#
# [4385 rows x 6 columns]

# %%
spy.fillna(method="ffill")
# Out:
#                   Open        High         Low       Close   Adj Close  \
# 2010-12-31  125.529999  125.870003  125.330002  125.750000   98.976181
# 2011-01-01  125.529999  125.870003  125.330002  125.750000   98.976181
# 2011-01-02  125.529999  125.870003  125.330002  125.750000   98.976181
# 2011-01-03  126.709999  127.599998  125.699997  127.050003   99.999397
# 2011-01-04  127.330002  127.370003  126.190002  126.980003   99.944298
# ...                ...         ...         ...         ...         ...
# 2022-12-28  381.329987  383.390015  376.420013  376.660004  372.525269
# 2022-12-29  379.630005  384.350006  379.079987  383.440002  379.230804
# 2022-12-30  380.640015  382.579987  378.429993  382.429993  378.231903
# 2022-12-31  380.640015  382.579987  378.429993  382.429993  378.231903
# 2023-01-01  380.640015  382.579987  378.429993  382.429993  378.231903
#
#                  Volume
# 2010-12-31   91218900.0
# 2011-01-01   91218900.0
# 2011-01-02   91218900.0
# 2011-01-03  138725200.0
# 2011-01-04  137409700.0
# ...                 ...
# 2022-12-28   70911500.0
# 2022-12-29   66970900.0
# 2022-12-30   84022200.0
# 2022-12-31   84022200.0
# 2023-01-01   84022200.0
#
# [4385 rows x 6 columns]

# %%
spy = spy[['Close']]
spy
# Out:
#                  Close
# 2010-12-31  125.750000
# 2011-01-01         NaN
# 2011-01-02         NaN
# 2011-01-03  127.050003
# 2011-01-04  126.980003
# ...                ...
# 2022-12-28  376.660004
# 2022-12-29  383.440002
# 2022-12-30  382.429993
# 2022-12-31         NaN
# 2023-01-01         NaN
#
# [4385 rows x 1 columns]

# %%
SPY=yf.download("SPY",interval="1wk")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
SPY
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1993-01-25   43.968750   43.968750   43.750000   43.937500   24.941397
# 1993-02-01   43.968750   45.093750   43.968750   44.968750   25.526794
# 1993-02-08   44.968750   45.125000   44.531250   44.593750   25.313923
# 1993-02-15   44.468750   44.468750   42.812500   43.562500   24.728518
# 1993-02-22   43.687500   44.437500   43.468750   44.406250   25.207481
# ...                ...         ...         ...         ...         ...
# 2023-09-11  448.239990  451.079987  442.920013  443.369995  441.811584
# 2023-09-18  443.049988  444.970001  429.989990  430.420013  430.420013
# 2023-09-25  429.170013  432.269989  422.290009  427.480011  427.480011
# 2023-10-02  426.619995  431.130005  420.179993  429.540009  429.540009
# 2023-10-09  427.579987  437.329987  427.010010  433.649109  433.649109
#
#                Volume
# Date
# 1993-01-25    1003200
# 1993-02-01    2234800
# 1993-02-08    1159800
# 1993-02-15     998700
# 1993-02-22    1024300
# ...               ...
# 2023-09-11  383137000
# 2023-09-18  409635200
# 2023-09-25  479085500
# 2023-10-02  458357600
# 2023-10-09  294025779
#
# [1603 rows x 6 columns]

# %%
apple=yf.download("AAPL")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
apple=apple.Close.to_frame()

# %%
apple.Close
# Out:
# Date
# 1980-12-12      0.128348
# 1980-12-15      0.121652
# 1980-12-16      0.112723
# 1980-12-17      0.115513
# 1980-12-18      0.118862
#                  ...
# 2023-10-06    177.490005
# 2023-10-09    178.990005
# 2023-10-10    178.389999
# 2023-10-11    179.800003
# 2023-10-12    180.750000
# Name: Close, Length: 10799, dtype: float64

# %%
apple["d_returns"]=np.log(apple.div(apple.shift(1)))
apple
# Out:
#                  Close  d_returns
# Date
# 1980-12-12    0.128348        NaN
# 1980-12-15    0.121652  -0.053581
# 1980-12-16    0.112723  -0.076231
# 1980-12-17    0.115513   0.024450
# 1980-12-18    0.118862   0.028580
# ...                ...        ...
# 2023-10-06  177.490005   0.014643
# 2023-10-09  178.990005   0.008416
# 2023-10-10  178.389999  -0.003358
# 2023-10-11  179.800003   0.007873
# 2023-10-12  180.750000   0.005270
#
# [10799 rows x 2 columns]

# %%
apple.dropna(inplace=True)
apple
# Out:
#                  Close  d_returns
# Date
# 1980-12-15    0.121652  -0.053581
# 1980-12-16    0.112723  -0.076231
# 1980-12-17    0.115513   0.024450
# 1980-12-18    0.118862   0.028580
# 1980-12-19    0.126116   0.059239
# ...                ...        ...
# 2023-10-06  177.490005   0.014643
# 2023-10-09  178.990005   0.008416
# 2023-10-10  178.389999  -0.003358
# 2023-10-11  179.800003   0.007873
# 2023-10-12  180.750000   0.005270
#
# [10798 rows x 2 columns]

# %%
apple.d_returns.sum()
# Out:
# 7.250124870558638

# %%
np.exp(apple.d_returns.sum())
# Out:
# 1408.2806900222163

# %%
apple["cummreturns"]=apple.d_returns.cumsum().apply(np.exp)

# %%
apple
# Out:
#                  Close  d_returns  cummreturns
# Date
# 1980-12-15    0.121652  -0.053581     0.947829
# 1980-12-16    0.112723  -0.076231     0.878261
# 1980-12-17    0.115513   0.024450     0.899998
# 1980-12-18    0.118862   0.028580     0.926092
# 1980-12-19    0.126116   0.059239     0.982610
# ...                ...        ...          ...
# 2023-10-06  177.490005   0.014643  1382.881037
# 2023-10-09  178.990005   0.008416  1394.568014
# 2023-10-10  178.389999  -0.003358  1389.893175
# 2023-10-11  179.800003   0.007873  1400.878962
# 2023-10-12  180.750000   0.005270  1408.280690
#
# [10798 rows x 3 columns]

# %%
apple.cummreturns.plot(figsize=(12,8),title="AAPL buy and hold", fontsize=12)
# Out:
# <Axes: title={'center': 'AAPL buy and hold'}, xlabel='Date'>

# %%
apple.d_returns.mean()*252
# Out:
# 0.16920091381559332

# %%
apple.d_returns.std()*np.sqrt(252)
# Out:
# 0.4525588868226008

# %%
# how to calc drawdowns
apple["cummax"]=apple.cummreturns.cummax()

# %%
apple
# Out:
#                  Close  d_returns  cummreturns       cummax
# Date
# 1980-12-15    0.121652  -0.053581     0.947829     0.947829
# 1980-12-16    0.112723  -0.076231     0.878261     0.947829
# 1980-12-17    0.115513   0.024450     0.899998     0.947829
# 1980-12-18    0.118862   0.028580     0.926092     0.947829
# 1980-12-19    0.126116   0.059239     0.982610     0.982610
# ...                ...        ...          ...          ...
# 2023-10-06  177.490005   0.014643  1382.881037  1530.604356
# 2023-10-09  178.990005   0.008416  1394.568014  1530.604356
# 2023-10-10  178.389999  -0.003358  1389.893175  1530.604356
# 2023-10-11  179.800003   0.007873  1400.878962  1530.604356
# 2023-10-12  180.750000   0.005270  1408.280690  1530.604356
#
# [10798 rows x 4 columns]

# %%
apple[["cummreturns","cummax"]].plot(figsize=(12,8),title="AAPL buy and hold+cummax", fontsize=12)
plt.show()

# %%
apple["drawdown"]=apple["cummax"]-apple["cummreturns"]

# %%
apple
# Out:
#                  Close  d_returns  cummreturns       cummax    drawdown
# Date
# 1980-12-15    0.121652  -0.053581     0.947829     0.947829    0.000000
# 1980-12-16    0.112723  -0.076231     0.878261     0.947829    0.069569
# 1980-12-17    0.115513   0.024450     0.899998     0.947829    0.047831
# 1980-12-18    0.118862   0.028580     0.926092     0.947829    0.021738
# 1980-12-19    0.126116   0.059239     0.982610     0.982610    0.000000
# ...                ...        ...          ...          ...         ...
# 2023-10-06  177.490005   0.014643  1382.881037  1530.604356  147.723319
# 2023-10-09  178.990005   0.008416  1394.568014  1530.604356  136.036342
# 2023-10-10  178.389999  -0.003358  1389.893175  1530.604356  140.711180
# 2023-10-11  179.800003   0.007873  1400.878962  1530.604356  129.725394
# 2023-10-12  180.750000   0.005270  1408.280690  1530.604356  122.323665
#
# [10798 rows x 5 columns]

# %%
apple.drawdown.max()
# Out:
# 444.02718404402026

# %%
apple.drawdown.idxmax()
# Out:
# Timestamp('2023-01-05 00:00:00')

# %%
apple.loc[(apple.index<='2023-01-05')]
# Out:
#                  Close  d_returns  cummreturns       cummax    drawdown
# Date
# 1980-12-15    0.121652  -0.053581     0.947829     0.947829    0.000000
# 1980-12-16    0.112723  -0.076231     0.878261     0.947829    0.069569
# 1980-12-17    0.115513   0.024450     0.899998     0.947829    0.047831
# 1980-12-18    0.118862   0.028580     0.926092     0.947829    0.021738
# 1980-12-19    0.126116   0.059239     0.982610     0.982610    0.000000
# ...                ...        ...          ...          ...         ...
# 2022-12-29  129.610001   0.027931  1009.832703  1418.097708  408.265004
# 2022-12-30  129.929993   0.002466  1012.325863  1418.097708  405.771845
# 2023-01-03  125.070000  -0.038122   974.460113  1418.097708  443.637594
# 2023-01-04  126.360001   0.010261   984.510920  1418.097708  433.586787
# 2023-01-05  125.019997  -0.010661   974.070524  1418.097708  444.027184
#
# [10605 rows x 5 columns]

# %%
apple["drawdown%"]=(apple["cummax"]-apple["cummreturns"])/apple["cummax"]

# %%
apple
# Out:
#                  Close  d_returns  cummreturns       cummax    drawdown  \
# Date
# 1980-12-15    0.121652  -0.053581     0.947829     0.947829    0.000000
# 1980-12-16    0.112723  -0.076231     0.878261     0.947829    0.069569
# 1980-12-17    0.115513   0.024450     0.899998     0.947829    0.047831
# 1980-12-18    0.118862   0.028580     0.926092     0.947829    0.021738
# 1980-12-19    0.126116   0.059239     0.982610     0.982610    0.000000
# ...                ...        ...          ...          ...         ...
# 2023-10-06  177.490005   0.014643  1382.881037  1530.604356  147.723319
# 2023-10-09  178.990005   0.008416  1394.568014  1530.604356  136.036342
# 2023-10-10  178.389999  -0.003358  1389.893175  1530.604356  140.711180
# 2023-10-11  179.800003   0.007873  1400.878962  1530.604356  129.725394
# 2023-10-12  180.750000   0.005270  1408.280690  1530.604356  122.323665
#
#             drawdown%
# Date
# 1980-12-15   0.000000
# 1980-12-16   0.073398
# 1980-12-17   0.050464
# 1980-12-18   0.022934
# 1980-12-19   0.000000
# ...               ...
# 2023-10-06   0.096513
# 2023-10-09   0.088878
# 2023-10-10   0.091932
# 2023-10-11   0.084754
# 2023-10-12   0.079919
#
# [10798 rows x 6 columns]

# %%
apple["drawdown%"].max()
# Out:
# 0.82216567924191

# %%
apple["drawdown%"].idxmax()
# Out:
# Timestamp('1997-12-23 00:00:00')

# %%
apple.loc[(apple.index<='1997-12-23')]
# Out:
#                Close  d_returns  cummreturns    cummax  drawdown  drawdown%
# Date
# 1980-12-15  0.121652  -0.053581     0.947829  0.947829  0.000000   0.000000
# 1980-12-16  0.112723  -0.076231     0.878261  0.947829  0.069569   0.073398
# 1980-12-17  0.115513   0.024450     0.899998  0.947829  0.047831   0.050464
# 1980-12-18  0.118862   0.028580     0.926092  0.947829  0.021738   0.022934
# 1980-12-19  0.126116   0.059239     0.982610  0.982610  0.000000   0.000000
# ...              ...        ...          ...       ...       ...        ...
# 1997-12-17  0.124442  -0.026549     0.969567  5.060882  4.091315   0.808419
# 1997-12-18  0.123326  -0.009008     0.960872  5.060882  4.100010   0.810137
# 1997-12-19  0.122210  -0.009090     0.952177  5.060882  4.108705   0.811856
# 1997-12-22  0.118862  -0.027778     0.926092  5.060882  4.134790   0.817010
# 1997-12-23  0.115513  -0.028580     0.899998  5.060882  4.160883   0.822166
#
# [4306 rows x 6 columns]

# %%
data=apple.Close.loc[(apple.index>='1991-01-01')]

# %%
data=data.to_frame()

# %%
data
# Out:
#                  Close
# Date
# 1991-01-02    0.388393
# 1991-01-03    0.383929
# 1991-01-04    0.386161
# 1991-01-07    0.386161
# 1991-01-08    0.386161
# ...                ...
# 2023-10-06  177.490005
# 2023-10-09  178.990005
# 2023-10-10  178.389999
# 2023-10-11  179.800003
# 2023-10-12  180.750000
#
# [8258 rows x 1 columns]

# %%
sma_s=50

# %%
sma_l=100

# %%
data["sma_s"]=data.Close.rolling(sma_s).mean()
data["sma_l"]=data.Close.rolling(sma_l).mean()

# %%
data
# Out:
#                  Close       sma_s     sma_l
# Date
# 1991-01-02    0.388393         NaN       NaN
# 1991-01-03    0.383929         NaN       NaN
# 1991-01-04    0.386161         NaN       NaN
# 1991-01-07    0.386161         NaN       NaN
# 1991-01-08    0.386161         NaN       NaN
# ...                ...         ...       ...
# 2023-10-06  177.490005  179.389401  182.1091
# 2023-10-09  178.990005  179.052601  182.1783
# 2023-10-10  178.389999  178.691401  182.2353
# 2023-10-11  179.800003  178.375201  182.2828
# 2023-10-12  180.750000  178.138601  182.3387
#
# [8258 rows x 3 columns]

# %%
data.plot(figsize=(12,9),title="AAPL - SMA{} | SMA{}".format(sma_s,sma_l),fontsize=12)
# Out:
# <Axes: title={'center': 'AAPL - SMA50 | SMA100'}, xlabel='Date'>

# %%
data.loc["2020":].plot(figsize=(12,9),title="AAPL - SMA{} | SMA{}".format(sma_s,sma_l),fontsize=12)
# Out:
# <Axes: title={'center': 'AAPL - SMA50 | SMA100'}, xlabel='Date'>

# %%
data.dropna(inplace=True)

# %%
data
# Out:
#                  Close       sma_s       sma_l
# Date
# 1991-05-23    0.402902    0.534420    0.513326
# 1991-05-24    0.409598    0.530960    0.513538
# 1991-05-28    0.410714    0.527344    0.513806
# 1991-05-29    0.419643    0.523638    0.514141
# 1991-05-30    0.425223    0.519732    0.514531
# ...                ...         ...         ...
# 2023-10-06  177.490005  179.389401  182.109100
# 2023-10-09  178.990005  179.052601  182.178300
# 2023-10-10  178.389999  178.691401  182.235300
# 2023-10-11  179.800003  178.375201  182.282800
# 2023-10-12  180.750000  178.138601  182.338700
#
# [8159 rows x 3 columns]

# %%
data["position"]=np.where(data["sma_s"]>data["sma_l"],1,-1)

# %%
data
# Out:
#                  Close       sma_s       sma_l  position
# Date
# 1991-05-23    0.402902    0.534420    0.513326         1
# 1991-05-24    0.409598    0.530960    0.513538         1
# 1991-05-28    0.410714    0.527344    0.513806         1
# 1991-05-29    0.419643    0.523638    0.514141         1
# 1991-05-30    0.425223    0.519732    0.514531         1
# ...                ...         ...         ...       ...
# 2023-10-06  177.490005  179.389401  182.109100        -1
# 2023-10-09  178.990005  179.052601  182.178300        -1
# 2023-10-10  178.389999  178.691401  182.235300        -1
# 2023-10-11  179.800003  178.375201  182.282800        -1
# 2023-10-12  180.750000  178.138601  182.338700        -1
#
# [8159 rows x 4 columns]

# %%
data.loc["2020":,["sma_s","sma_l","position"]].plot(figsize=(12,8),title="AAPL - SMA{} | SMA{}".format(sma_s,sma_l),fontsize=12, secondary_y="position")
# Out:
# <Axes: title={'center': 'AAPL - SMA50 | SMA100'}, xlabel='Date'>

# %%
data["returnsb&h"]=np.log(data.Close.div(data.Close.shift(1)))

# %%
data
# Out:
#                  Close       sma_s       sma_l  position  returnsb&h
# Date
# 1991-05-23    0.402902    0.534420    0.513326         1         NaN
# 1991-05-24    0.409598    0.530960    0.513538         1    0.016483
# 1991-05-28    0.410714    0.527344    0.513806         1    0.002721
# 1991-05-29    0.419643    0.523638    0.514141         1    0.021507
# 1991-05-30    0.425223    0.519732    0.514531         1    0.013209
# ...                ...         ...         ...       ...         ...
# 2023-10-06  177.490005  179.389401  182.109100        -1    0.014643
# 2023-10-09  178.990005  179.052601  182.178300        -1    0.008416
# 2023-10-10  178.389999  178.691401  182.235300        -1   -0.003358
# 2023-10-11  179.800003  178.375201  182.282800        -1    0.007873
# 2023-10-12  180.750000  178.138601  182.338700        -1    0.005270
#
# [8159 rows x 5 columns]

# %%
data["strategy"]=data["returnsb&h"]*data.position.shift(1)

# %%
data
# Out:
#                  Close       sma_s       sma_l  position  returnsb&h  strategy
# Date
# 1991-05-23    0.402902    0.534420    0.513326         1         NaN       NaN
# 1991-05-24    0.409598    0.530960    0.513538         1    0.016483  0.016483
# 1991-05-28    0.410714    0.527344    0.513806         1    0.002721  0.002721
# 1991-05-29    0.419643    0.523638    0.514141         1    0.021507  0.021507
# 1991-05-30    0.425223    0.519732    0.514531         1    0.013209  0.013209
# ...                ...         ...         ...       ...         ...       ...
# 2023-10-06  177.490005  179.389401  182.109100        -1    0.014643 -0.014643
# 2023-10-09  178.990005  179.052601  182.178300        -1    0.008416 -0.008416
# 2023-10-10  178.389999  178.691401  182.235300        -1   -0.003358  0.003358
# 2023-10-11  179.800003  178.375201  182.282800        -1    0.007873 -0.007873
# 2023-10-12  180.750000  178.138601  182.338700        -1    0.005270 -0.005270
#
# [8159 rows x 6 columns]

# %%
data.dropna(inplace=True)

# %%
data[["returnsb&h","strategy"]].sum()
# Out:
# returnsb&h    6.106177
# strategy      2.029886
# dtype: float64

# %%
data[["returnsb&h","strategy"]].sum().apply(np.exp) # 1 dollar investment
# Out:
# returnsb&h    448.620252
# strategy        7.613216
# dtype: float64

# %%
data[["returnsb&h","strategy"]].std()*np.sqrt(252) #annual std
# Out:
# returnsb&h    0.436180
# strategy      0.436323
# dtype: float64

# %%
data.Close.plot(figsize=(12,8))
# Out:
# <Axes: xlabel='Date'>

# %%
data["position2"]=np.where(data["sma_s"]>data["sma_l"],1,0)

# %%
data["strategy2"]=data["returnsb&h"]*data.position2.shift(1)

# %%
data
# Out:
#                  Close       sma_s       sma_l  position  returnsb&h  \
# Date
# 1991-05-24    0.409598    0.530960    0.513538         1    0.016483
# 1991-05-28    0.410714    0.527344    0.513806         1    0.002721
# 1991-05-29    0.419643    0.523638    0.514141         1    0.021507
# 1991-05-30    0.425223    0.519732    0.514531         1    0.013209
# 1991-05-31    0.419643    0.516027    0.514866         1   -0.013209
# ...                ...         ...         ...       ...         ...
# 2023-10-06  177.490005  179.389401  182.109100        -1    0.014643
# 2023-10-09  178.990005  179.052601  182.178300        -1    0.008416
# 2023-10-10  178.389999  178.691401  182.235300        -1   -0.003358
# 2023-10-11  179.800003  178.375201  182.282800        -1    0.007873
# 2023-10-12  180.750000  178.138601  182.338700        -1    0.005270
#
#             strategy  position2  strategy2
# Date
# 1991-05-24  0.016483          1        NaN
# 1991-05-28  0.002721          1   0.002721
# 1991-05-29  0.021507          1   0.021507
# 1991-05-30  0.013209          1   0.013209
# 1991-05-31 -0.013209          1  -0.013209
# ...              ...        ...        ...
# 2023-10-06 -0.014643          0   0.000000
# 2023-10-09 -0.008416          0   0.000000
# 2023-10-10  0.003358          0  -0.000000
# 2023-10-11 -0.007873          0   0.000000
# 2023-10-12 -0.005270          0   0.000000
#
# [8158 rows x 8 columns]

# %%
data.dropna(inplace=True)

# %%
data
# Out:
#                  Close       sma_s       sma_l  position  returnsb&h  \
# Date
# 1991-05-28    0.410714    0.527344    0.513806         1    0.002721
# 1991-05-29    0.419643    0.523638    0.514141         1    0.021507
# 1991-05-30    0.425223    0.519732    0.514531         1    0.013209
# 1991-05-31    0.419643    0.516027    0.514866         1   -0.013209
# 1991-06-03    0.439732    0.513259    0.515223        -1    0.046761
# ...                ...         ...         ...       ...         ...
# 2023-10-06  177.490005  179.389401  182.109100        -1    0.014643
# 2023-10-09  178.990005  179.052601  182.178300        -1    0.008416
# 2023-10-10  178.389999  178.691401  182.235300        -1   -0.003358
# 2023-10-11  179.800003  178.375201  182.282800        -1    0.007873
# 2023-10-12  180.750000  178.138601  182.338700        -1    0.005270
#
#             strategy  position2  strategy2
# Date
# 1991-05-28  0.002721          1   0.002721
# 1991-05-29  0.021507          1   0.021507
# 1991-05-30  0.013209          1   0.013209
# 1991-05-31 -0.013209          1  -0.013209
# 1991-06-03  0.046761          0   0.046761
# ...              ...        ...        ...
# 2023-10-06 -0.014643          0   0.000000
# 2023-10-09 -0.008416          0   0.000000
# 2023-10-10  0.003358          0  -0.000000
# 2023-10-11 -0.007873          0   0.000000
# 2023-10-12 -0.005270          0   0.000000
#
# [8157 rows x 8 columns]

# %%
data[["returnsb&h","strategy2"]].sum()
# Out:
# returnsb&h    6.089694
# strategy2     4.051548
# dtype: float64

# %%
data[["returnsb&h","strategy2"]].sum().apply(np.exp) # 1 dollar investment
# Out:
# returnsb&h    441.286342
# strategy2      57.486403
# dtype: float64

# %%
data[["returnsb&h","strategy2"]].std()*np.sqrt(252) #annual std
# Out:
# returnsb&h    0.436197
# strategy2     0.337293
# dtype: float64

# %%
## strat 2 is better than strat 1

# %%
data[["strategy","strategy2"]].std()*np.sqrt(252) #annual std
# Out:
# strategy     0.436341
# strategy2    0.337293
# dtype: float64

# %%
def test_strategy(stock,start,end,SMA):
    df = yf.download(stock,start=start,end=end)
    data = df.Close.to_frame()
    data["Returns"]=np.log(data.Close.div(data.Close.shift(1)))
    data["SMA_S"]=data.Close.rolling(int(SMA[0])).mean()
    data["SMA_L"]=data.Close.rolling(int(SMA[1])).mean()
    data.dropna(inplace=True)
    
    data["position"]=np.where(data["SMA_S"]>data["SMA_L"],1,-1)
    data["strategy"]=data["Returns"]*data.position.shift(1)
    data.dropna(inplace=True)
    ret=np.exp(data["strategy"].sum())
    std= data["strategy"].std()*np.sqrt(252)
    
    return ret,std

# %%
test_strategy("AAPL","2000-01-01","2023-01-01", (50,200))
# Out:
# [*********************100%%**********************]  1 of 1 completed
# (31.177007359630633, 0.3672557952294945)

# %%
class SMAbacktester():
    def __init__(self, symbol,SMA_S,SMA_L,start,end):
        self.symbol=symbol
        self.SMA_S=SMA_S
        self.SMA_L=SMA_L
        self.start=start
        self.end=end
        self.results=None
        self.get_data()
    
    def get_data(self):
        df=yf.download(self.symbol,start=self.start,end=self.end)
        data=df.Close.to_frame()
        data["returns"]=np.log(data.Close.div(data.Close.shift(1)))
        data["SMA_S"]=data.Close.rolling(self.SMA_S).mean()
        data["SMA_L"]=data.Close.rolling(self.SMA_L).mean()
        data.dropna(inplace=True)
        self.data2=data
        
        return data
    
    def test_results(self):
        data=self.data2.copy().dropna()
        data["position"]=np.where(data["SMA_S"]>data["SMA_L"],1,-1)
        data["strategy"]=data["returns"]*data.position.shift(1)
        data.dropna(inplace=True)
        data["returnsbh"]=data["returns"].cumsum().apply(np.exp)
        data["returnsstrategy"]=data["strategy"].cumsum().apply(np.exp)
        perf=data["returnsstrategy"].iloc[-1]
        outperf=perf-data["returnsbh"].iloc[-1]
        self.results=data
        
        ret=np.exp(data["strategy"].sum())
        std=data["strategy"].std()*np.sqrt(252)
        
        #return ret,std
        return round(perf,6), round(outperf,6)
    
    def plot_results(self):
        if self.results is None:
            print("Run the test please")
            
        else:
            title="{}| SMA_S={} | SMA_L={}".format(self.symbol,self.SMA_S,self.SMA_L)
            self.results[["returnsbh","returnsstrategy"]].plot(title=title, figsize=(12,8))

# %%
tester = SMAbacktester("SPY",50,100,"2000-01-01","2023-01-01")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
tester.test_results()
# Out:
# (1.689963, -1.036811)

# %%
tester.plot_results()
